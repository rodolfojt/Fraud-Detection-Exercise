# %% [markdown]
# # Detecção de Fraudes em Pagamentos de Cartão de Crédito
#
# Esse notebook é uma tradução com comentários do exercício realizado no notebook ['Fraud_Detection_Exercise.ipynb'](https://github.com/udacity/ML_SageMaker_Studies/blob/master/Payment_Fraud_Detection/Fraud_Detection_Exercise.ipynb) durante o programa de Machine Learning Engineer Nanodegree da Udacity.
#
# Neste exercício, nós iremos analisar um conjunto de dados de transações de cartão de crédito válidas e fraudulentas para construir um modelo de classificação binária que pode identificar transações como fraudulentas ou válidas, baseado nos dados históricos.Em um [estudo de 2016](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), foi estimado que o problema de fraudes em cartões de crédito eram responsáveis por mais de 20 bilhões de dólares em prejuízo ao redor do mundo. Detectar casos de fraude com precisão é uma área de pesquisa em desenvolvimento.
# <img src=notebook_img/fraud_detection.png width=50% />
#
# ### Dados Rotulados
#
# O conjunto de dados rotulados (Dal Pozzolo et al. 2015) foi baixado do [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data).
# Nele temos milhares de transações de cartão de crédito com features e labels indicando se o registro é de uma transação fraudulenta ou válida.
# Neste notebook, nós vamos treinar um modelo baseado nas features dessas transações de tal forma que poderemos prever uma transação suspeita ou fraudulenta no futuro.
#
# ### Classificação Binária
#
# Uma vez que nosso modelo usará os rótulos para aprender a detectar fraudes, nós usaremos uma **abordagem supervisionada** e treinar um classificador binário para predizer dois tipos de classes de transações: fraudulenta ou válida. Treinaremos o modelo em um conjunto de treinamento e veremos como é seu desempenho em um conjunto de dados de teste.
#
# As etapas abordadas aqui serão:
# * Carregar e explorar os dados
# * Dividir o conjunto de dados em conjunto de treinamento e teste
# * Definir e treinar um classificador binário: LinerLearner
# * Fazer melhorias no modelo
# * Avaliar e comparar o desempenho do modelo com os dados de teste
#
# ### Adicionando melhorias
#
# Uma grande parte deste notebook irá focar em fazer melhorias no modelo, uma vez que o problema de detecção de fraude é frequentemente um problema de classificação com classes desbalanceadas. Dessa forma, nós iremos aumentar o desempenho do nosso modelo aplicando as seguintes técnicas:
#
# 1. **Ajustar os hiperparâmetros do modelo** de modo a atingir um valor específico de uma métrica, como atingir o mínio de 85% de acurácia ou 85% de recall.
# 2. **Lidar com o desbalanceamento de classes**, que ocorre quando temos muito mais exemplos de uma classe do que outra(no nosso casso esperamos encontrar muito mais transações válidas do que fraudulentas).
#
# ---

# %% [markdown]
# Primeiro vamos importar as bibliotecas que iremos usar.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

import boto3
import sagemaker
from sagemaker import get_execution_role
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# Iremos armazenar nossas **variáveis do SageMaker** no próxima célula:
# * sagemaker_session: A sessão do SageMaker que iremos usar para o treinamento dos modelos.
# * bucket: O nome do bucket S3 padrão que iremos usar para o armazenamento de dados.
# * role: A IAM role que define as permissões dos dados e modelo.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Carregando e Explorando os Dados
#
# Em seguida, iremos carregar os dados e descompactá-los do arquivo `creditcardfraud.zip`. Esse diretório irá armazenar um arquivo '.csv' com todas as transações, `creditcard.csv`.
#
# É importante olhar para a distribuição dos dados uma vez que isso irá nos informar como devemos desenvolver o modelo de detecção de fraudes. Nós precisaremos saber: quantos registros nós temos para trabalhar, o número e o tipo das features, e finalmente, a distribuição dos dados para cada classe (válida e fraudulenta).

# %%
# only have to run once
# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# !unzip creditcardfraud

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Calculando a porcentagem de transações fraudulentas
#
# Vamos dar uma olhada na distribuição das transações para cada classe, válida e fraudulenta.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    percentage = transaction_df.Class.values.sum()/len(transaction_df)
    
    return percentage

# %% [markdown]
# Vamos testar o código chamando a função `fraudulent_percentage()`.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage)
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.001727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# Podemos ver que temos aproximadamente 285 mil registros, desses apenas 492 registros de fraudes. Ou seja, apenas 0,1% são registros de transações fraudulentas, enquanto que 99,9% dos registro são de transações válidas. O que comprova que temos um conjunto de dados com classes desbalenceadas.

# %% [markdown]
# ### Dividindo o conjunto de dados em conjunto de treinamento e teste
#
# Após o treinamento do modelo, nós vamos precisar testar a performance do classificador em um conjunto de dados novo que não deve ser visto pelo modelo durante o treinamento. Por isso, vamos dividir o conjunto de dados de 285 mil registros em conjunto de treinamento (70%) e conjunto de teste (30%).

# %%
# split into train/test
def split_train_test(transaction_df, train_frac= 0.7, seed=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: Two tuples (in order): (train_features, train_labels), (test_features, test_labels)
       '''
    X = transaction_df.iloc[:,:-1].copy()
    y = transaction_df.iloc[:,-1:].copy()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1-train_frac, random_state=seed)
    
    # shuffle and split the data
    train_features = X_train
    train_labels = y_train
    test_features = X_test
    test_labels = y_test
    
    return (train_features, train_labels), (test_features, test_labels)

# %% [markdown]
# ### Executando a divisão dos conjuntos

# %% [markdown]
# Abaixo iremos efetivamente executar a divisão em conjunto de treinamento e conjunto de testes, passando como argumento da função `split_train_test()` nosso dataframe `transaction_df` e porcentagem do conjunto de treinamento que definiremos como 0.7 (70%).

# %%
# get train/test data
(train_features, train_labels), (test_features, test_labels) = split_train_test(transaction_df, train_frac=0.7)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features[:1])
print('Label: ', train_labels[:1])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#              Time        V1        V2        V3        V4        V5        V6  \
# 191125  129124.0 -0.190075  0.203323 -0.996232 -1.596985  3.192579  3.356935
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 191125  0.288299  0.895003 -0.330024  ... -0.007496 -0.170599 -0.619724
#
#              V23       V24      V25       V26       V27       V28  Amount
# 191125  0.039651  0.706805 -0.16087  0.274825 -0.010541  0.022199   14.37
#
# [1 rows x 30 columns]
# Label:          Class
# 191125      0
#
# Tests passed!

# %% [markdown]
# ---
# ## Modelagem
#
# Agora que nós jpa carregamos e dividimos os dados de treinamento, podemos seguir para definir e treinar um modelo.
#
# Neste notebook, iremos utilizar um algoritmo do Amazon SageMaker, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# Um modelo LinearLearner tem duas aplicações principais:
# 1. Para problemas de regressão as quais uma linha linear se adequad alguns pontos de dados e você quer prever um valor de saída  dado alguns dados de entrada (exemplo: prever o preço de casas, dada a área quadrada)
# 2. Para classificação binária, à qual uma linha consegue separar duas classes de dados e efetivamente dois rótulos; 1 para dados que caem acima da linha e 0 para pontos que caem em cima ou abaixo da linha.
#
# <img src='notebook_img/linear_separator.png' width=50% />
#
# No caso da detecção de fraude, nós iremos usar o segundo caso e iremos treinar nosso classificador para separar dados em duas classes: válidas ou fraudulentas.

# %% [markdown]
# ### Criando um estimador LinearLearner
#
# Usando a documentação do [SageMaker LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) como referência, vamos descobrir quais são os principais parâmetros necessários para inicializar o nosso estimador.
#
# #### Tipos de instância
#
# Foi sugerido que nós usássemos as intâncias que estão disponíveis gratuitamente para uso: `'ml.c4.xlarge'` para treinamento e `'ml.t2.medium'` para implantação do modelo.

# %%
# import LinearLearner
from sagemaker import LinearLearner

prefix = 'creditcard'
output_path = 's3://{}/{}'.format(bucket, prefix)

# instantiate LinearLearner
linear_learner = LinearLearner(
                    role=role,
                    train_instance_count=1, 
                    train_instance_type='ml.c4.xlarge', 
                    predictor_type='binary_classifier',
                    output_path=output_path,
                    sagemaker_session=sagemaker_session,
                    epochs=15)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Convertendo dados no formato RecordSet
#
# Para que possamos inputar nossas transações históricas no modelo é preciso converter as features e labels do conjunto de treinamento para o formato de dados *RecordSet*. No entanto, para usarmos a função [record_set](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) precisaremos converter as features e labels para vetores numpy de valores float.

# %%
# convert features and labels to numpy
train_features = train_features.astype('float32')
train_labels = train_labels.astype('float32')

# create RecordSet of training data
formatted_train_data = linear_learner.record_set(train_features.values, labels=train_labels.values.reshape(-1,))

# %% [markdown]
# ### Treinando o Classificador

# %% [markdown]
# Depois de instanciar nosso estimador, podemos iniciar o treinamento chamando o método `.fit()`, passando os dados de treinamento formatados.

# %%
# %%time 
# train the estimator on formatted training data
linear_learner.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-21 22:28:29 Starting - Starting the training job...
# 2021-02-21 22:28:31 Starting - Launching requested ML instancesProfilerReport-1613946509: InProgress
# ......
# 2021-02-21 22:29:59 Starting - Preparing the instances for training............
# 2021-02-21 22:31:47 Downloading - Downloading input data
# 2021-02-21 22:31:47 Training - Downloading the training image...
# 2021-02-21 22:32:27 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/21/2021 22:32:19 INFO 139904509531968] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/21/2021 22:32:19 INFO 139904509531968] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'15', u'feature_dim': u'30', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [02/21/2021 22:32:19 INFO 139904509531968] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/21/2021 22:32:19 WARNING 139904509531968] Loggers have already been setup.
# Process 1 is a worker.
# [02/21/2021 22:32:19 INFO 139904509531968] Using default worker.
# [02/21/2021 22:32:19 INFO 139904509531968] Checkpoint loading and saving are disabled.
# [2021-02-21 22:32:19.317] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 22, "num_examples": 1, "num_bytes": 168000}
# [02/21/2021 22:32:19 INFO 139904509531968] Create Store: local
# [2021-02-21 22:32:19.459] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 141, "num_examples": 11, "num_bytes": 1848000}
# [02/21/2021 22:32:19 INFO 139904509531968] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3daf181d90>
# [02/21/2021 22:32:19 INFO 139904509531968] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/21/2021 22:32:19 INFO 139904509531968] nvidia-smi took: 0.0251288414001 secs to identify 0 gpus
# [02/21/2021 22:32:19 INFO 139904509531968] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1613946739.564303, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613946739.564264}
#
# [2021-02-21 22:32:25.951] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6386, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12023840661743777, "sum": 0.12023840661743777, "min": 0.12023840661743777}}, "EndTime": 1613946745.951448, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951344}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1175625283514435, "sum": 0.1175625283514435, "min": 0.1175625283514435}}, "EndTime": 1613946745.95156, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951539}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12012009677216036, "sum": 0.12012009677216036, "min": 0.12012009677216036}}, "EndTime": 1613946745.951632, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951614}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11766779350395777, "sum": 0.11766779350395777, "min": 0.11766779350395777}}, "EndTime": 1613946745.9517, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951681}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012220082102483841, "sum": 0.012220082102483841, "min": 0.012220082102483841}}, "EndTime": 1613946745.951778, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951759}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012175582823441855, "sum": 0.012175582823441855, "min": 0.012175582823441855}}, "EndTime": 1613946745.951852, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951833}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012201707582415348, "sum": 0.012201707582415348, "min": 0.012201707582415348}}, "EndTime": 1613946745.951918, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.9519}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012345536659747811, "sum": 0.012345536659747811, "min": 0.012345536659747811}}, "EndTime": 1613946745.95198, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.951964}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12014251477035445, "sum": 0.12014251477035445, "min": 0.12014251477035445}}, "EndTime": 1613946745.95205, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952032}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11776210052643589, "sum": 0.11776210052643589, "min": 0.11776210052643589}}, "EndTime": 1613946745.95213, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.95211}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12038165889912514, "sum": 0.12038165889912514, "min": 0.12038165889912514}}, "EndTime": 1613946745.952203, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952184}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11770791634602762, "sum": 0.11770791634602762, "min": 0.11770791634602762}}, "EndTime": 1613946745.952271, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952252}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01261257816119185, "sum": 0.01261257816119185, "min": 0.01261257816119185}}, "EndTime": 1613946745.952343, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952324}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012488340938866289, "sum": 0.012488340938866289, "min": 0.012488340938866289}}, "EndTime": 1613946745.952407, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.95239}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012396600667237486, "sum": 0.012396600667237486, "min": 0.012396600667237486}}, "EndTime": 1613946745.952475, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952455}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012499406192096035, "sum": 0.012499406192096035, "min": 0.012499406192096035}}, "EndTime": 1613946745.95254, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952522}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1228250465488913, "sum": 0.1228250465488913, "min": 0.1228250465488913}}, "EndTime": 1613946745.952604, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952587}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12008383270723735, "sum": 0.12008383270723735, "min": 0.12008383270723735}}, "EndTime": 1613946745.952667, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952649}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12283358952507901, "sum": 0.12283358952507901, "min": 0.12283358952507901}}, "EndTime": 1613946745.952731, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952712}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12025850340109974, "sum": 0.12025850340109974, "min": 0.12025850340109974}}, "EndTime": 1613946745.952836, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952814}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019943902858238126, "sum": 0.019943902858238126, "min": 0.019943902858238126}}, "EndTime": 1613946745.952913, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952894}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01993385848758658, "sum": 0.01993385848758658, "min": 0.01993385848758658}}, "EndTime": 1613946745.952986, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.952966}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019987651391170133, "sum": 0.019987651391170133, "min": 0.019987651391170133}}, "EndTime": 1613946745.95306, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.95304}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01984426697302404, "sum": 0.01984426697302404, "min": 0.01984426697302404}}, "EndTime": 1613946745.953134, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953115}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12367208990739219, "sum": 0.12367208990739219, "min": 0.12367208990739219}}, "EndTime": 1613946745.953204, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953186}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12108522349985401, "sum": 0.12108522349985401, "min": 0.12108522349985401}}, "EndTime": 1613946745.953272, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953253}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12374423226399638, "sum": 0.12374423226399638, "min": 0.12374423226399638}}, "EndTime": 1613946745.95334, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.95332}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12116944918800239, "sum": 0.12116944918800239, "min": 0.12116944918800239}}, "EndTime": 1613946745.953413, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953392}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02103997616806821, "sum": 0.02103997616806821, "min": 0.02103997616806821}}, "EndTime": 1613946745.953476, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953459}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020920196363487135, "sum": 0.020920196363487135, "min": 0.020920196363487135}}, "EndTime": 1613946745.953545, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953528}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021012824348543756, "sum": 0.021012824348543756, "min": 0.021012824348543756}}, "EndTime": 1613946745.953615, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953596}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021031404245476327, "sum": 0.021031404245476327, "min": 0.021031404245476327}}, "EndTime": 1613946745.953684, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946745.953666}
#
# [02/21/2021 22:32:25 INFO 139904509531968] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120238406617
# [02/21/2021 22:32:25 INFO 139904509531968] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0121755828234
# [02/21/2021 22:32:25 INFO 139904509531968] Epoch 0: Loss improved. Updating best model
# [02/21/2021 22:32:25 INFO 139904509531968] Saving model for epoch: 0
# [02/21/2021 22:32:25 INFO 139904509531968] Saved checkpoint to "/tmp/tmplgAi5o/mx-mod-0000.params"
# [02/21/2021 22:32:25 INFO 139904509531968] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1613946745.968421, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613946739.564553}
#
# [02/21/2021 22:32:25 INFO 139904509531968] #throughput_metric: host=algo-1, train throughput=31131.2269159 records/second
# [2021-02-21 22:32:33.003] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7027, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016883339575187645, "sum": 0.016883339575187645, "min": 0.016883339575187645}}, "EndTime": 1613946753.003499, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003412}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014893327607581363, "sum": 0.014893327607581363, "min": 0.014893327607581363}}, "EndTime": 1613946753.003592, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.00357}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01687481061178236, "sum": 0.01687481061178236, "min": 0.01687481061178236}}, "EndTime": 1613946753.003655, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003637}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014889016120278056, "sum": 0.014889016120278056, "min": 0.014889016120278056}}, "EndTime": 1613946753.003726, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003707}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0054091289906046496, "sum": 0.0054091289906046496, "min": 0.0054091289906046496}}, "EndTime": 1613946753.003792, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003774}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0055940955086569094, "sum": 0.0055940955086569094, "min": 0.0055940955086569094}}, "EndTime": 1613946753.00386, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003837}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00551705657522283, "sum": 0.00551705657522283, "min": 0.00551705657522283}}, "EndTime": 1613946753.003923, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003905}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005566651671825342, "sum": 0.005566651671825342, "min": 0.005566651671825342}}, "EndTime": 1613946753.003985, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.003967}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0170403941312627, "sum": 0.0170403941312627, "min": 0.0170403941312627}}, "EndTime": 1613946753.004051, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004033}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015086053342675444, "sum": 0.015086053342675444, "min": 0.015086053342675444}}, "EndTime": 1613946753.004115, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004098}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.017052275235928484, "sum": 0.017052275235928484, "min": 0.017052275235928484}}, "EndTime": 1613946753.004187, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.00417}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015078012080647837, "sum": 0.015078012080647837, "min": 0.015078012080647837}}, "EndTime": 1613946753.004249, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004231}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005623061710715893, "sum": 0.005623061710715893, "min": 0.005623061710715893}}, "EndTime": 1613946753.004308, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004292}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005685889098512468, "sum": 0.005685889098512468, "min": 0.005685889098512468}}, "EndTime": 1613946753.004366, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004349}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005619973746376421, "sum": 0.005619973746376421, "min": 0.005619973746376421}}, "EndTime": 1613946753.004426, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004407}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005672148302122576, "sum": 0.005672148302122576, "min": 0.005672148302122576}}, "EndTime": 1613946753.004482, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004467}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02126987413665158, "sum": 0.02126987413665158, "min": 0.02126987413665158}}, "EndTime": 1613946753.00454, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004523}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019476390440859387, "sum": 0.019476390440859387, "min": 0.019476390440859387}}, "EndTime": 1613946753.004599, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004581}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02127108111932649, "sum": 0.02127108111932649, "min": 0.02127108111932649}}, "EndTime": 1613946753.004656, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004641}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01948852028679009, "sum": 0.01948852028679009, "min": 0.01948852028679009}}, "EndTime": 1613946753.004715, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004698}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012074755899271174, "sum": 0.012074755899271174, "min": 0.012074755899271174}}, "EndTime": 1613946753.004807, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004787}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012111119604589951, "sum": 0.012111119604589951, "min": 0.012111119604589951}}, "EndTime": 1613946753.00487, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004852}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01207915733866955, "sum": 0.01207915733866955, "min": 0.01207915733866955}}, "EndTime": 1613946753.004926, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004909}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01210820182843424, "sum": 0.01210820182843424, "min": 0.01210820182843424}}, "EndTime": 1613946753.00498, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.004963}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.022298133768627992, "sum": 0.022298133768627992, "min": 0.022298133768627992}}, "EndTime": 1613946753.005041, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005024}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020528922866936306, "sum": 0.020528922866936306, "min": 0.020528922866936306}}, "EndTime": 1613946753.005102, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005084}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.022301760285343957, "sum": 0.022301760285343957, "min": 0.022301760285343957}}, "EndTime": 1613946753.005154, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005138}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020534939981585173, "sum": 0.020534939981585173, "min": 0.020534939981585173}}, "EndTime": 1613946753.005209, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005192}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01314413232719479, "sum": 0.01314413232719479, "min": 0.01314413232719479}}, "EndTime": 1613946753.005266, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005251}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013147845992490874, "sum": 0.013147845992490874, "min": 0.013147845992490874}}, "EndTime": 1613946753.005321, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005306}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013144269559251603, "sum": 0.013144269559251603, "min": 0.013144269559251603}}, "EndTime": 1613946753.005378, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005361}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013148174486567627, "sum": 0.013148174486567627, "min": 0.013148174486567627}}, "EndTime": 1613946753.005437, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946753.005419}
#
# [02/21/2021 22:32:33 INFO 139904509531968] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0168833395752
# [02/21/2021 22:32:33 INFO 139904509531968] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906
# [02/21/2021 22:32:33 INFO 139904509531968] Epoch 1: Loss improved. Updating best model
# [02/21/2021 22:32:33 INFO 139904509531968] Saving model for epoch: 1
# [02/21/2021 22:32:33 INFO 139904509531968] Saved checkpoint to "/tmp/tmpdCYbiZ/mx-mod-0000.params"
# [02/21/2021 22:32:33 INFO 139904509531968] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1613946753.012772, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613946745.970333}
#
# [02/21/2021 22:32:33 INFO 139904509531968] #throughput_metric: host=algo-1, train throughput=28308.396194 records/second
# [2021-02-21 22:32:39.522] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6507, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010249469512671083, "sum": 0.010249469512671083, "min": 0.010249469512671083}}, "EndTime": 1613946759.522393, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522296}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008671593309047832, "sum": 0.008671593309047832, "min": 0.008671593309047832}}, "EndTime": 1613946759.522493, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522469}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010244108916527063, "sum": 0.010244108916527063, "min": 0.010244108916527063}}, "EndTime": 1613946759.522567, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522546}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00867205645930228, "sum": 0.00867205645930228, "min": 0.00867205645930228}}, "EndTime": 1613946759.522631, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522612}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004918119081076066, "sum": 0.004918119081076066, "min": 0.004918119081076066}}, "EndTime": 1613946759.522704, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522684}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005651303291320801, "sum": 0.005651303291320801, "min": 0.005651303291320801}}, "EndTime": 1613946759.522761, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522743}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0049273479259643125, "sum": 0.0049273479259643125, "min": 0.0049273479259643125}}, "EndTime": 1613946759.522815, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522799}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005490868361226878, "sum": 0.005490868361226878, "min": 0.005490868361226878}}, "EndTime": 1613946759.522878, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.52286}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010515944255656334, "sum": 0.010515944255656334, "min": 0.010515944255656334}}, "EndTime": 1613946759.522939, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522922}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009003221483086821, "sum": 0.009003221483086821, "min": 0.009003221483086821}}, "EndTime": 1613946759.523003, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.522985}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010521823832737141, "sum": 0.010521823832737141, "min": 0.010521823832737141}}, "EndTime": 1613946759.523078, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523049}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008999888767549142, "sum": 0.008999888767549142, "min": 0.008999888767549142}}, "EndTime": 1613946759.523141, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523124}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005593623910117988, "sum": 0.005593623910117988, "min": 0.005593623910117988}}, "EndTime": 1613946759.523203, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523184}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005721277174338624, "sum": 0.005721277174338624, "min": 0.005721277174338624}}, "EndTime": 1613946759.523265, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523248}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005546630558656089, "sum": 0.005546630558656089, "min": 0.005546630558656089}}, "EndTime": 1613946759.52333, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523312}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005712993024581641, "sum": 0.005712993024581641, "min": 0.005712993024581641}}, "EndTime": 1613946759.523393, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523374}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015533093172102119, "sum": 0.015533093172102119, "min": 0.015533093172102119}}, "EndTime": 1613946759.523454, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523435}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0142904183541111, "sum": 0.0142904183541111, "min": 0.0142904183541111}}, "EndTime": 1613946759.523513, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523496}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01553408638556399, "sum": 0.01553408638556399, "min": 0.01553408638556399}}, "EndTime": 1613946759.523581, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523563}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014295967495022108, "sum": 0.014295967495022108, "min": 0.014295967495022108}}, "EndTime": 1613946759.523642, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523625}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012072144002171617, "sum": 0.012072144002171617, "min": 0.012072144002171617}}, "EndTime": 1613946759.523697, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523681}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0121305170963757, "sum": 0.0121305170963757, "min": 0.0121305170963757}}, "EndTime": 1613946759.523754, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523739}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012072037987373583, "sum": 0.012072037987373583, "min": 0.012072037987373583}}, "EndTime": 1613946759.523812, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523796}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012126008991021007, "sum": 0.012126008991021007, "min": 0.012126008991021007}}, "EndTime": 1613946759.523869, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523852}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016575735899671238, "sum": 0.016575735899671238, "min": 0.016575735899671238}}, "EndTime": 1613946759.523931, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523914}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01536184029123891, "sum": 0.01536184029123891, "min": 0.01536184029123891}}, "EndTime": 1613946759.523992, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.523975}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01657752835451059, "sum": 0.01657752835451059, "min": 0.01657752835451059}}, "EndTime": 1613946759.52405, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.524033}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01536392712712887, "sum": 0.01536392712712887, "min": 0.01536392712712887}}, "EndTime": 1613946759.52411, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.524093}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013144806580327862, "sum": 0.013144806580327862, "min": 0.013144806580327862}}, "EndTime": 1613946759.524163, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.524146}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013156182020153832, "sum": 0.013156182020153832, "min": 0.013156182020153832}}, "EndTime": 1613946759.524221, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.524205}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013145586877012972, "sum": 0.013145586877012972, "min": 0.013145586877012972}}, "EndTime": 1613946759.524282, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.524265}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01315547815998595, "sum": 0.01315547815998595, "min": 0.01315547815998595}}, "EndTime": 1613946759.52434, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946759.524324}
#
# [02/21/2021 22:32:39 INFO 139904509531968] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.0102494695127
# [02/21/2021 22:32:39 INFO 139904509531968] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00491811908108
# [02/21/2021 22:32:39 INFO 139904509531968] Epoch 2: Loss improved. Updating best model
# [02/21/2021 22:32:39 INFO 139904509531968] Saving model for epoch: 2
# [02/21/2021 22:32:39 INFO 139904509531968] Saved checkpoint to "/tmp/tmpvGoNTK/mx-mod-0000.params"
# [02/21/2021 22:32:39 INFO 139904509531968] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1613946759.531237, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613946753.014655}
#
# [02/21/2021 22:32:39 INFO 139904509531968] #throughput_metric: host=algo-1, train throughput=30592.7935078 records/second
# [2021-02-21 22:32:45.829] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6296, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00796071047279703, "sum": 0.00796071047279703, "min": 0.00796071047279703}}, "EndTime": 1613946765.829217, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613946765.829108}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0066089136300973555, "sum": 0.0066089136300973555, "min": 0.0066089136300973555}}, "EndTime": 1613946765.829326, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613946765.829303}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007957086086273194, "sum": 0.007957086086273194, "min": 0.007957086086273194}}, "EndTime": 1613946765.829395, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613946765.829378}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006610484449108642, "sum": 0.006610484449108642, "min": 0.006610484449108642}}, "EndTime": 1613946765.829433, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613946765.829424}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0041351939227113775, "sum": 0.0041351939227113775, "min": 0.0041351939227113775}}, "EndTime": 1613946835.501087, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501069}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0040303359740044, "sum": 0.0040303359740044, "min": 0.0040303359740044}}, "EndTime": 1613946835.501152, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501133}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005875211362862707, "sum": 0.005875211362862707, "min": 0.005875211362862707}}, "EndTime": 1613946835.501223, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501204}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00404278004139512, "sum": 0.00404278004139512, "min": 0.00404278004139512}}, "EndTime": 1613946835.501288, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.50127}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005471848284853763, "sum": 0.005471848284853763, "min": 0.005471848284853763}}, "EndTime": 1613946835.501349, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501331}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0055071240819279275, "sum": 0.0055071240819279275, "min": 0.0055071240819279275}}, "EndTime": 1613946835.501409, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501391}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093599353004341, "sum": 0.005093599353004341, "min": 0.005093599353004341}}, "EndTime": 1613946835.501473, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501455}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005507833725243956, "sum": 0.005507833725243956, "min": 0.005507833725243956}}, "EndTime": 1613946835.501541, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501525}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093542199638022, "sum": 0.005093542199638022, "min": 0.005093542199638022}}, "EndTime": 1613946835.501605, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501588}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0050990720678813495, "sum": 0.0050990720678813495, "min": 0.0050990720678813495}}, "EndTime": 1613946835.501664, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501647}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005519994659040441, "sum": 0.005519994659040441, "min": 0.005519994659040441}}, "EndTime": 1613946835.501724, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501708}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005098994569862308, "sum": 0.005098994569862308, "min": 0.005098994569862308}}, "EndTime": 1613946835.501783, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501766}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005520632858851448, "sum": 0.005520632858851448, "min": 0.005520632858851448}}, "EndTime": 1613946835.501843, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501826}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012167769629751617, "sum": 0.012167769629751617, "min": 0.012167769629751617}}, "EndTime": 1613946835.501904, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501887}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012054018840118868, "sum": 0.012054018840118868, "min": 0.012054018840118868}}, "EndTime": 1613946835.501962, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.501947}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012167777455631811, "sum": 0.012167777455631811, "min": 0.012167777455631811}}, "EndTime": 1613946835.50202, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502005}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012054238608135051, "sum": 0.012054238608135051, "min": 0.012054238608135051}}, "EndTime": 1613946835.502053, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502045}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012039981996593762, "sum": 0.012039981996593762, "min": 0.012039981996593762}}, "EndTime": 1613946835.50208, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502072}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012189195263625389, "sum": 0.012189195263625389, "min": 0.012189195263625389}}, "EndTime": 1613946835.502134, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502118}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012040088680521328, "sum": 0.012040088680521328, "min": 0.012040088680521328}}, "EndTime": 1613946835.502196, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502179}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012187875629968979, "sum": 0.012187875629968979, "min": 0.012187875629968979}}, "EndTime": 1613946835.502254, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502239}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013193741987698042, "sum": 0.013193741987698042, "min": 0.013193741987698042}}, "EndTime": 1613946835.502318, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.5023}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013127850090438997, "sum": 0.013127850090438997, "min": 0.013127850090438997}}, "EndTime": 1613946835.502377, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502361}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013193773884270059, "sum": 0.013193773884270059, "min": 0.013193773884270059}}, "EndTime": 1613946835.502439, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502422}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013127679164685196, "sum": 0.013127679164685196, "min": 0.013127679164685196}}, "EndTime": 1613946835.502504, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502487}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013136238493512024, "sum": 0.013136238493512024, "min": 0.013136238493512024}}, "EndTime": 1613946835.502558, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502547}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013258359701190162, "sum": 0.013258359701190162, "min": 0.013258359701190162}}, "EndTime": 1613946835.502606, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502593}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013136125135062328, "sum": 0.013136125135062328, "min": 0.013136125135062328}}, "EndTime": 1613946835.502674, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.502655}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013257740079757557, "sum": 0.013257740079757557, "min": 0.013257740079757557}}, "EndTime": 1613946835.502738, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946835.50272}
#
# [02/21/2021 22:33:55 INFO 139904509531968] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00479624264983
# [02/21/2021 22:33:55 INFO 139904509531968] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.004030335974
# [02/21/2021 22:33:55 INFO 139904509531968] Epoch 14: Loss improved. Updating best model
# [02/21/2021 22:33:55 INFO 139904509531968] Saving model for epoch: 14
# [02/21/2021 22:33:55 INFO 139904509531968] Saved checkpoint to "/tmp/tmpXKK4UY/mx-mod-0000.params"
# [02/21/2021 22:33:55 INFO 139904509531968] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1613946835.509532, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613946829.059558}
#
# [02/21/2021 22:33:55 INFO 139904509531968] #throughput_metric: host=algo-1, train throughput=30908.7837382 records/second
# [02/21/2021 22:33:55 WARNING 139904509531968] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/21/2021 22:33:55 WARNING 139904509531968] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-02-21 22:33:55.516] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-02-21 22:33:56.199] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 680, "num_examples": 200, "num_bytes": 33493152}
# [2021-02-21 22:33:57.002] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 733, "num_examples": 200, "num_bytes": 33493152}
# [02/21/2021 22:33:57 INFO 139904509531968] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/21/2021 22:33:57 INFO 139904509531968] #train_score (algo-1) : ('binary_classification_accuracy', 0.9992827190465681)
# [02/21/2021 22:33:57 INFO 139904509531968] #train_score (algo-1) : ('binary_f_1.000', 0.7971631205673759)
# [02/21/2021 22:33:57 INFO 139904509531968] #train_score (algo-1) : ('precision', 0.8074712643678161)
# [02/21/2021 22:33:57 INFO 139904509531968] #train_score (algo-1) : ('recall', 0.7871148459383753)
# [02/21/2021 22:33:57 INFO 139904509531968] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/21/2021 22:33:57 INFO 139904509531968] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00396091186531
# [02/21/2021 22:33:57 INFO 139904509531968] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999282719047
# [02/21/2021 22:33:57 INFO 139904509531968] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.797163120567
# [02/21/2021 22:33:57 INFO 139904509531968] #quality_metric: host=algo-1, train precision <score>=0.807471264368
# [02/21/2021 22:33:57 INFO 139904509531968] #quality_metric: host=algo-1, train recall <score>=0.787114845938
# [02/21/2021 22:33:57 INFO 139904509531968] #quality_metric: host=algo-1, train roc_auc_score <score>=0.979089470538
# [02/21/2021 22:33:57 INFO 139904509531968] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [02/21/2021 22:33:57 INFO 139904509531968] Saved checkpoint to "/tmp/tmpLASwnq/mx-mod-0000.params"
# [02/21/2021 22:33:57 INFO 139904509531968] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 98022.92394638062, "sum": 98022.92394638062, "min": 98022.92394638062}, "finalize.time": {"count": 1, "max": 1551.3319969177246, "sum": 1551.3319969177246, "min": 1551.3319969177246}, "initialize.time": {"count": 1, "max": 264.62793350219727, "sum": 264.62793350219727, "min": 264.62793350219727}, "check_early_stopping.time": {"count": 15, "max": 1.1410713195800781, "sum": 13.367891311645508, "min": 0.7801055908203125}, "setuptime": {"count": 1, "max": 26.205062866210938, "sum": 26.205062866210938, "min": 26.205062866210938}, "update.time": {"count": 15, "max": 7157.268047332764, "sum": 95879.52756881714, "min": 5928.697824478149}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1613946837.066292, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613946739.294037}
#
#
# 2021-02-21 22:34:28 Completed - Training job completed
# ProfilerReport-1613946509: NoIssuesFound
# Training seconds: 154
# Billable seconds: 154
# CPU times: user 994 ms, sys: 51.7 ms, total: 1.05 s
# Wall time: 6min 14s

# %% [markdown]
# ### Implantando o modelo treinado

# %% [markdown]
# Para criar um preditor nós precisaremos implantar o modelo treinado. Faremos isso usando o método `.deploy()` e usaremos o nosso preditor para gerar predições no conjunto de teste.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linear_learner.deploy(initial_instance_count = 1, instance_type = 'ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------------!CPU times: user 324 ms, sys: 4.94 ms, total: 329 ms
# Wall time: 8min 32s

# %% [markdown]
# ---
# ## Avaliando Nosso Modelo
#
# Uma vez que o modelo está implantando, poderemos usá-lo para gerar predições no conjunto de teste.
#
# De acordo com a [documentação de preditores](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor) esse preditor espera um `ndarray` de entrada e retorna uma lista de Records.
#
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Vamos primeiro testar nosso modelo usando apenas um registro de teste, para ver o que ele retorna.

# %%
# test one prediction
test_x_np = test_features.astype('float32')
result = linear_predictor.predict(test_x_np[:1].values)

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0002751190622802824
#     }
#   }
# }
# ]

# %% [markdown]
# ### Função auxiliar para avaliação
#
# A função que foi fornecida abaixo, usa um preditor implantado, algumas features de teste e rótulos, e retorna um dicionário de métricas, calculando falsos negativos e positivos, assim como também recall, precisão e acurácia.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Testando os Resultados
#
# A célula abaixo executa a função `evaluate()`.
#
# O código assume que já tenhamos um `predictor` definido, `test_features` e `test_labels` executados de células anteriores.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.astype('float32').values, 
                   test_labels.values.reshape(-1,), 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85282   26
# 1                    36   99
#
# Recall:     0.733
# Precision:  0.792
# Accuracy:   0.999

# %% [markdown]
# ### Deletando o Endpoint
#
# Foi também fornecido uma função para deletar o endpoint de predição depois que finalizarmos com os testes. E caso você tenha terminado de avaliar o modelo, é extremamente recomendado que você delete o endpoint do seu modelo.

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-02-21-22-46-05-756

# %% [markdown]
# ---
#
# ## Melhorias no Modelo
#
# O LinearLearner padrão obteve uma acurácia alta, porém nós ainda obtemos previsões equivocadas de transações fraudulentas e válidas com frequência. Especificamente classificamos mais de 30 pontos como falsos positivos (incorretamente rotulados, transações válidas). Vamos pensar sobre o que, durante o treinamento, poderia causar esse comportamento e o que podemos fazer para melhorar o modelo nesse quesito.
#
# **1. Otimização do modelo**
#
# * Se nós imaginármos que nós estamos projetando esse modelo para uso em uma aplicação bancária, nós podemos deduzir que nossos usuários *não* querem que qualquer transação válida seja classificada como fraudulenta. Isto é, nós desejamos obter o mínimo de **falsos positivos** (0s classificados como 1s).
# * Por outro lado, se nosso gerente do banco pedir por uma aplicação que irá detectar quase que todos os casos de fraudes, mesmo que isso signifique um alto número de falsos positivos, então nós iríamos querer obter o mínimo de falsos negativos.
# * Para treinar nosso modelo de acordo com objetivos e demandas do produto específicos, nós não devemos otimizar apenas a acurácia do nosso modelo. Ao invés disso, queremos otimizar para uma métrica que pode nos ajudar a diminuir o número de falsos positivos ou negativos.
#
# <img src='notebook_img/precision_recall.png' width=40% />
#
# Neste notebook, nós iremos olhar para casos diferentes para ajustar nosso modelo e tomar decisões de otimização de acordo com cada caso.
#
# **2. Dados de treinamento desbalanceados**
# * No começo deste notebook, nó vimos que apenas 0.17% dos dados de treinamento foram rotuladas como fraudulentas. Dessa forma, mesmo se nosso modelo predizer **todas** as transações como sendo válidas, ele ainda terá uma alta acurácia.
# * Isso pode resultar em um certo overfitting relacionado às transações válidas, que é responsável por alguns **falsos negativos**, onde transações fraudulentas (1) são incorretamente classificadas como válidas (0).
#
# Portanto, vamos solucionar esses problemas em ordem; primeiro, ajustando nosso modelo e otimizando-o para um métrica específica durante o treinamento. Em seguida, ajustar o modelo para lidar com o desbalanceamento das classes no conjunto de treinamento.
#
# ## 1ª Melhoria: Ajuste do Modelo
#
# Otimizar de acordo com uma métrica específica é chamado de ajuste do modelo (model tuning). O SageMaker fornece diversos modos para ajustar um modelo.
#
# ### Cenário:
#
# * Uma fintech solicita que você construa um modelo que detecta casos de fraude com uma acurácia de aproximadamente 85%.
#
# Nesse caso, nós queremos construir um modelo que obtenha o maior número possível de verdadeiros positivos e o menor número de falsos negativos. Isso corresponde a um modelo com alto **recall**: verdadeiros positivos / (verdadeiros positivos + falsos negativos).
#
# Para ajustar o modelo de acordo com uma métrica específica, LinerLearner oferece o hiperparâmetro `binary_classifier_model_selection_criteria`, o qual é um critério de avaliação para o conjunto de dados de treinamento. Uma referência sobre esse parâmetro pode ser lida na [documentação do LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). Nós precisaremos também especificar o valor exato que queremos atingir.
#
# Para ler mais sobre detalhes dos parâmetros, [clique aqui](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# Nós iremos assumir aqui que o desempenho do modelo no conjunto de treinamento estará dentro de aproximadamente 5% do desempenho no conjunto de testes. Por isso, para um recall de aproximadamente 85%, nós iremos definir uma meta de 90% no conjunto de treinamento.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Trainando um estimador ajustado
#
# Vamos treinar o novo modelo ajustado no conjunto de treinamento formatado.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-21 23:18:30 Starting - Starting the training job...ProfilerReport-1613949510: InProgress
# ...
# 2021-02-21 23:19:25 Starting - Launching requested ML instances.........
# 2021-02-21 23:20:46 Starting - Preparing the instances for training...
# 2021-02-21 23:21:26 Downloading - Downloading input data...
# 2021-02-21 23:21:47 Training - Downloading the training image...
# 2021-02-21 23:22:27 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/21/2021 23:22:29 INFO 140054048798528] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/21/2021 23:22:29 INFO 140054048798528] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'feature_dim': u'30', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [02/21/2021 23:22:29 INFO 140054048798528] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/21/2021 23:22:29 WARNING 140054048798528] Loggers have already been setup.
# Process 1 is a worker.
# [02/21/2021 23:22:29 INFO 140054048798528] Using default worker.
# [02/21/2021 23:22:29 INFO 140054048798528] Checkpoint loading and saving are disabled.
# [2021-02-21 23:22:29.632] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 32, "num_examples": 1, "num_bytes": 168000}
# [02/21/2021 23:22:29 INFO 140054048798528] Create Store: local
# [2021-02-21 23:22:29.718] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 85, "num_examples": 11, "num_bytes": 1848000}
# [02/21/2021 23:22:29 INFO 140054048798528] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f6080584d50>
# [02/21/2021 23:22:29 INFO 140054048798528] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/21/2021 23:22:29 INFO 140054048798528] nvidia-smi took: 0.0251801013947 secs to identify 0 gpus
# [02/21/2021 23:22:29 INFO 140054048798528] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1613949749.820191, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613949749.82015}
#
# [2021-02-21 23:22:36.368] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6548, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12023840661743777, "sum": 0.12023840661743777, "min": 0.12023840661743777}}, "EndTime": 1613949756.369132, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369019}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1175625283514435, "sum": 0.1175625283514435, "min": 0.1175625283514435}}, "EndTime": 1613949756.369264, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369238}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12012009677216036, "sum": 0.12012009677216036, "min": 0.12012009677216036}}, "EndTime": 1613949756.369345, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369324}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11766779350395777, "sum": 0.11766779350395777, "min": 0.11766779350395777}}, "EndTime": 1613949756.369448, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369425}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012220082102483841, "sum": 0.012220082102483841, "min": 0.012220082102483841}}, "EndTime": 1613949756.369512, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369493}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012175582823441855, "sum": 0.012175582823441855, "min": 0.012175582823441855}}, "EndTime": 1613949756.36958, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369561}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012201707582415348, "sum": 0.012201707582415348, "min": 0.012201707582415348}}, "EndTime": 1613949756.369645, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369626}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012345536659747811, "sum": 0.012345536659747811, "min": 0.012345536659747811}}, "EndTime": 1613949756.369714, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369693}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12014251477035445, "sum": 0.12014251477035445, "min": 0.12014251477035445}}, "EndTime": 1613949756.369792, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369773}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11776210052643589, "sum": 0.11776210052643589, "min": 0.11776210052643589}}, "EndTime": 1613949756.369856, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369839}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12038165889912514, "sum": 0.12038165889912514, "min": 0.12038165889912514}}, "EndTime": 1613949756.36992, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369902}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11770791634602762, "sum": 0.11770791634602762, "min": 0.11770791634602762}}, "EndTime": 1613949756.369985, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.369967}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01261257816119185, "sum": 0.01261257816119185, "min": 0.01261257816119185}}, "EndTime": 1613949756.370051, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370031}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012488340938866289, "sum": 0.012488340938866289, "min": 0.012488340938866289}}, "EndTime": 1613949756.370114, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370096}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012396600667237486, "sum": 0.012396600667237486, "min": 0.012396600667237486}}, "EndTime": 1613949756.370179, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370161}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012499406192096035, "sum": 0.012499406192096035, "min": 0.012499406192096035}}, "EndTime": 1613949756.370243, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370225}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1228250465488913, "sum": 0.1228250465488913, "min": 0.1228250465488913}}, "EndTime": 1613949756.370308, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370289}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12008383270723735, "sum": 0.12008383270723735, "min": 0.12008383270723735}}, "EndTime": 1613949756.370371, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370353}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12283358952507901, "sum": 0.12283358952507901, "min": 0.12283358952507901}}, "EndTime": 1613949756.370434, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370415}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12025850340109974, "sum": 0.12025850340109974, "min": 0.12025850340109974}}, "EndTime": 1613949756.370483, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370467}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019943902858238126, "sum": 0.019943902858238126, "min": 0.019943902858238126}}, "EndTime": 1613949756.370548, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.37053}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01993385848758658, "sum": 0.01993385848758658, "min": 0.01993385848758658}}, "EndTime": 1613949756.370612, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370594}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019987651391170133, "sum": 0.019987651391170133, "min": 0.019987651391170133}}, "EndTime": 1613949756.370681, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370661}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01984426697302404, "sum": 0.01984426697302404, "min": 0.01984426697302404}}, "EndTime": 1613949756.370754, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370735}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12367208990739219, "sum": 0.12367208990739219, "min": 0.12367208990739219}}, "EndTime": 1613949756.370813, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370796}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12108522349985401, "sum": 0.12108522349985401, "min": 0.12108522349985401}}, "EndTime": 1613949756.370877, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370859}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12374423226399638, "sum": 0.12374423226399638, "min": 0.12374423226399638}}, "EndTime": 1613949756.370949, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.37093}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12116944918800239, "sum": 0.12116944918800239, "min": 0.12116944918800239}}, "EndTime": 1613949756.371015, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.370996}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02103997616806821, "sum": 0.02103997616806821, "min": 0.02103997616806821}}, "EndTime": 1613949756.37108, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.371062}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020920196363487135, "sum": 0.020920196363487135, "min": 0.020920196363487135}}, "EndTime": 1613949756.371145, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.371126}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021012824348543756, "sum": 0.021012824348543756, "min": 0.021012824348543756}}, "EndTime": 1613949756.371211, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.371192}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021031404245476327, "sum": 0.021031404245476327, "min": 0.021031404245476327}}, "EndTime": 1613949756.371277, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949756.371259}
#
# [02/21/2021 23:22:36 INFO 140054048798528] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120238406617
# [02/21/2021 23:22:36 INFO 140054048798528] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0121755828234
# [02/21/2021 23:22:36 INFO 140054048798528] Epoch 0: Loss improved. Updating best model
# [02/21/2021 23:22:36 INFO 140054048798528] Saving model for epoch: 0
# [02/21/2021 23:22:36 INFO 140054048798528] Saved checkpoint to "/tmp/tmpyliHwR/mx-mod-0000.params"
# [02/21/2021 23:22:36 INFO 140054048798528] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1613949756.382454, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613949749.820448}
#
# [02/21/2021 23:22:36 INFO 140054048798528] #throughput_metric: host=algo-1, train throughput=30380.9759725 records/second
# [2021-02-21 23:22:43.177] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6792, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016883339575187645, "sum": 0.016883339575187645, "min": 0.016883339575187645}}, "EndTime": 1613949763.17717, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177065}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014893327607581363, "sum": 0.014893327607581363, "min": 0.014893327607581363}}, "EndTime": 1613949763.17727, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177249}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01687481061178236, "sum": 0.01687481061178236, "min": 0.01687481061178236}}, "EndTime": 1613949763.177347, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177327}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014889016120278056, "sum": 0.014889016120278056, "min": 0.014889016120278056}}, "EndTime": 1613949763.177452, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177429}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0054091289906046496, "sum": 0.0054091289906046496, "min": 0.0054091289906046496}}, "EndTime": 1613949763.177523, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177504}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0055940955086569094, "sum": 0.0055940955086569094, "min": 0.0055940955086569094}}, "EndTime": 1613949763.177595, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177575}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00551705657522283, "sum": 0.00551705657522283, "min": 0.00551705657522283}}, "EndTime": 1613949763.177662, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177644}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005566651671825342, "sum": 0.005566651671825342, "min": 0.005566651671825342}}, "EndTime": 1613949763.177726, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177708}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0170403941312627, "sum": 0.0170403941312627, "min": 0.0170403941312627}}, "EndTime": 1613949763.177786, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177769}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015086053342675444, "sum": 0.015086053342675444, "min": 0.015086053342675444}}, "EndTime": 1613949763.177851, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177835}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.017052275235928484, "sum": 0.017052275235928484, "min": 0.017052275235928484}}, "EndTime": 1613949763.177913, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177895}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015078012080647837, "sum": 0.015078012080647837, "min": 0.015078012080647837}}, "EndTime": 1613949763.177958, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.177943}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005623061710715893, "sum": 0.005623061710715893, "min": 0.005623061710715893}}, "EndTime": 1613949763.178017, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178001}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005685889098512468, "sum": 0.005685889098512468, "min": 0.005685889098512468}}, "EndTime": 1613949763.178072, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178059}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005619973746376421, "sum": 0.005619973746376421, "min": 0.005619973746376421}}, "EndTime": 1613949763.178105, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178096}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005672148302122576, "sum": 0.005672148302122576, "min": 0.005672148302122576}}, "EndTime": 1613949763.178164, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178147}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02126987413665158, "sum": 0.02126987413665158, "min": 0.02126987413665158}}, "EndTime": 1613949763.178222, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178205}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019476390440859387, "sum": 0.019476390440859387, "min": 0.019476390440859387}}, "EndTime": 1613949763.178263, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178253}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02127108111932649, "sum": 0.02127108111932649, "min": 0.02127108111932649}}, "EndTime": 1613949763.178302, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178288}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01948852028679009, "sum": 0.01948852028679009, "min": 0.01948852028679009}}, "EndTime": 1613949763.178335, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178326}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012074755899271174, "sum": 0.012074755899271174, "min": 0.012074755899271174}}, "EndTime": 1613949763.178385, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178369}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012111119604589951, "sum": 0.012111119604589951, "min": 0.012111119604589951}}, "EndTime": 1613949763.178443, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178428}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01207915733866955, "sum": 0.01207915733866955, "min": 0.01207915733866955}}, "EndTime": 1613949763.178494, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178483}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01210820182843424, "sum": 0.01210820182843424, "min": 0.01210820182843424}}, "EndTime": 1613949763.178538, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178524}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.022298133768627992, "sum": 0.022298133768627992, "min": 0.022298133768627992}}, "EndTime": 1613949763.178578, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178564}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020528922866936306, "sum": 0.020528922866936306, "min": 0.020528922866936306}}, "EndTime": 1613949763.17865, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178632}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.022301760285343957, "sum": 0.022301760285343957, "min": 0.022301760285343957}}, "EndTime": 1613949763.178709, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178697}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.020534939981585173, "sum": 0.020534939981585173, "min": 0.020534939981585173}}, "EndTime": 1613949763.178748, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178739}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01314413232719479, "sum": 0.01314413232719479, "min": 0.01314413232719479}}, "EndTime": 1613949763.178801, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.17879}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013147845992490874, "sum": 0.013147845992490874, "min": 0.013147845992490874}}, "EndTime": 1613949763.178847, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178832}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013144269559251603, "sum": 0.013144269559251603, "min": 0.013144269559251603}}, "EndTime": 1613949763.1789, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178889}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013148174486567627, "sum": 0.013148174486567627, "min": 0.013148174486567627}}, "EndTime": 1613949763.178962, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949763.178944}
#
# [02/21/2021 23:22:43 INFO 140054048798528] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0168833395752
# [02/21/2021 23:22:43 INFO 140054048798528] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906
# [02/21/2021 23:22:43 INFO 140054048798528] Epoch 1: Loss improved. Updating best model
# [02/21/2021 23:22:43 INFO 140054048798528] Saving model for epoch: 1
# [02/21/2021 23:22:43 INFO 140054048798528] Saved checkpoint to "/tmp/tmpuau29Q/mx-mod-0000.params"
# [02/21/2021 23:22:43 INFO 140054048798528] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1613949763.188388, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613949756.384146}
#
# [02/21/2021 23:22:43 INFO 140054048798528] #throughput_metric: host=algo-1, train throughput=29299.4320992 records/second
# [2021-02-21 23:22:49.752] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6562, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010249469512671083, "sum": 0.010249469512671083, "min": 0.010249469512671083}}, "EndTime": 1613949769.75315, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.752865}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008671593309047832, "sum": 0.008671593309047832, "min": 0.008671593309047832}}, "EndTime": 1613949769.753257, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753238}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010244108916527063, "sum": 0.010244108916527063, "min": 0.010244108916527063}}, "EndTime": 1613949769.753324, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753307}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00867205645930228, "sum": 0.00867205645930228, "min": 0.00867205645930228}}, "EndTime": 1613949769.753419, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753397}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004918119081076066, "sum": 0.004918119081076066, "min": 0.004918119081076066}}, "EndTime": 1613949769.753488, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753468}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005651303291320801, "sum": 0.005651303291320801, "min": 0.005651303291320801}}, "EndTime": 1613949769.753565, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753544}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0049273479259643125, "sum": 0.0049273479259643125, "min": 0.0049273479259643125}}, "EndTime": 1613949769.753649, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.75363}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005490868361226878, "sum": 0.005490868361226878, "min": 0.005490868361226878}}, "EndTime": 1613949769.753715, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753696}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010515944255656334, "sum": 0.010515944255656334, "min": 0.010515944255656334}}, "EndTime": 1613949769.75379, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753771}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009003221483086821, "sum": 0.009003221483086821, "min": 0.009003221483086821}}, "EndTime": 1613949769.753867, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753847}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010521823832737141, "sum": 0.010521823832737141, "min": 0.010521823832737141}}, "EndTime": 1613949769.753937, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753919}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008999888767549142, "sum": 0.008999888767549142, "min": 0.008999888767549142}}, "EndTime": 1613949769.753995, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.753979}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005593623910117988, "sum": 0.005593623910117988, "min": 0.005593623910117988}}, "EndTime": 1613949769.754053, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754037}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005721277174338624, "sum": 0.005721277174338624, "min": 0.005721277174338624}}, "EndTime": 1613949769.754125, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754106}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005546630558656089, "sum": 0.005546630558656089, "min": 0.005546630558656089}}, "EndTime": 1613949769.754187, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754169}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005712993024581641, "sum": 0.005712993024581641, "min": 0.005712993024581641}}, "EndTime": 1613949769.754249, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754231}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.015533093172102119, "sum": 0.015533093172102119, "min": 0.015533093172102119}}, "EndTime": 1613949769.754309, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754291}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0142904183541111, "sum": 0.0142904183541111, "min": 0.0142904183541111}}, "EndTime": 1613949769.754381, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.75436}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01553408638556399, "sum": 0.01553408638556399, "min": 0.01553408638556399}}, "EndTime": 1613949769.754447, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754428}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.014295967495022108, "sum": 0.014295967495022108, "min": 0.014295967495022108}}, "EndTime": 1613949769.754518, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.7545}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012072144002171617, "sum": 0.012072144002171617, "min": 0.012072144002171617}}, "EndTime": 1613949769.754584, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754566}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0121305170963757, "sum": 0.0121305170963757, "min": 0.0121305170963757}}, "EndTime": 1613949769.754647, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754629}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012072037987373583, "sum": 0.012072037987373583, "min": 0.012072037987373583}}, "EndTime": 1613949769.754707, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.75469}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012126008991021007, "sum": 0.012126008991021007, "min": 0.012126008991021007}}, "EndTime": 1613949769.754763, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754747}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016575735899671238, "sum": 0.016575735899671238, "min": 0.016575735899671238}}, "EndTime": 1613949769.754832, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754813}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01536184029123891, "sum": 0.01536184029123891, "min": 0.01536184029123891}}, "EndTime": 1613949769.754893, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754876}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01657752835451059, "sum": 0.01657752835451059, "min": 0.01657752835451059}}, "EndTime": 1613949769.754961, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.754943}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01536392712712887, "sum": 0.01536392712712887, "min": 0.01536392712712887}}, "EndTime": 1613949769.755024, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.755006}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013144806580327862, "sum": 0.013144806580327862, "min": 0.013144806580327862}}, "EndTime": 1613949769.755081, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.755064}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013156182020153832, "sum": 0.013156182020153832, "min": 0.013156182020153832}}, "EndTime": 1613949769.755139, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.755123}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013145586877012972, "sum": 0.013145586877012972, "min": 0.013145586877012972}}, "EndTime": 1613949769.755197, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.75518}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01315547815998595, "sum": 0.01315547815998595, "min": 0.01315547815998595}}, "EndTime": 1613949769.755259, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949769.755241}
#
# [02/21/2021 23:22:49 INFO 140054048798528] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.0102494695127
# [02/21/2021 23:22:49 INFO 140054048798528] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00491811908108
# [02/21/2021 23:22:49 INFO 140054048798528] Epoch 2: Loss improved. Updating best model
# [02/21/2021 23:22:49 INFO 140054048798528] Saving model for epoch: 2
# [02/21/2021 23:22:49 INFO 140054048798528] Saved checkpoint to "/tmp/tmpLYN6Xq/mx-mod-0000.params"
# [02/21/2021 23:22:49 INFO 140054048798528] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1613949769.763256, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613949763.190178}
#
# [02/21/2021 23:22:49 INFO 140054048798528] #throughput_metric: host=algo-1, train throughput=30329.819792 records/second
# [2021-02-21 23:22:55.883] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6118, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00796071047279703, "sum": 0.00796071047279703, "min": 0.00796071047279703}}, "EndTime": 1613949775.883451, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613949775.883344}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0066089136300973555, "sum": 0.0066089136300973555, "min": 0.0066089136300973555}}, "EndTime": 1613949775.883563, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613949775.883541}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007957086086273194, "sum": 0.007957086086273194, "min": 0.007957086086273194}}, "EndTime": 1613949775.883645, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613949775.883625}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006610484449108642, "sum": 0.006610484449108642, "min": 0.006610484449108642}}, "EndTime": 1613949775.883714, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613949775.883694}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0041351939227113775, "sum": 0.0041351939227113775, "min": 0.0041351939227113775}}, "EndTime": 1613949848.065115, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065094}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0040303359740044, "sum": 0.0040303359740044, "min": 0.0040303359740044}}, "EndTime": 1613949848.065197, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065176}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005875211362862707, "sum": 0.005875211362862707, "min": 0.005875211362862707}}, "EndTime": 1613949848.065266, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065247}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00404278004139512, "sum": 0.00404278004139512, "min": 0.00404278004139512}}, "EndTime": 1613949848.065334, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065314}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005471848284853763, "sum": 0.005471848284853763, "min": 0.005471848284853763}}, "EndTime": 1613949848.065427, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065407}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0055071240819279275, "sum": 0.0055071240819279275, "min": 0.0055071240819279275}}, "EndTime": 1613949848.065495, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065476}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093599353004341, "sum": 0.005093599353004341, "min": 0.005093599353004341}}, "EndTime": 1613949848.06557, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065552}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005507833725243956, "sum": 0.005507833725243956, "min": 0.005507833725243956}}, "EndTime": 1613949848.065633, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065616}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005093542199638022, "sum": 0.005093542199638022, "min": 0.005093542199638022}}, "EndTime": 1613949848.065707, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065688}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0050990720678813495, "sum": 0.0050990720678813495, "min": 0.0050990720678813495}}, "EndTime": 1613949848.065781, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065762}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005519994659040441, "sum": 0.005519994659040441, "min": 0.005519994659040441}}, "EndTime": 1613949848.065855, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065836}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005098994569862308, "sum": 0.005098994569862308, "min": 0.005098994569862308}}, "EndTime": 1613949848.065921, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065904}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005520632858851448, "sum": 0.005520632858851448, "min": 0.005520632858851448}}, "EndTime": 1613949848.065987, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.065969}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012167769629751617, "sum": 0.012167769629751617, "min": 0.012167769629751617}}, "EndTime": 1613949848.066053, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066037}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012054018840118868, "sum": 0.012054018840118868, "min": 0.012054018840118868}}, "EndTime": 1613949848.066114, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066098}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012167777455631811, "sum": 0.012167777455631811, "min": 0.012167777455631811}}, "EndTime": 1613949848.066176, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066158}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012054238608135051, "sum": 0.012054238608135051, "min": 0.012054238608135051}}, "EndTime": 1613949848.066248, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066229}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012039981996593762, "sum": 0.012039981996593762, "min": 0.012039981996593762}}, "EndTime": 1613949848.066315, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066297}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012189195263625389, "sum": 0.012189195263625389, "min": 0.012189195263625389}}, "EndTime": 1613949848.066377, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.06636}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012040088680521328, "sum": 0.012040088680521328, "min": 0.012040088680521328}}, "EndTime": 1613949848.066439, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066423}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012187875629968979, "sum": 0.012187875629968979, "min": 0.012187875629968979}}, "EndTime": 1613949848.066501, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066483}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013193741987698042, "sum": 0.013193741987698042, "min": 0.013193741987698042}}, "EndTime": 1613949848.06656, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066543}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013127850090438997, "sum": 0.013127850090438997, "min": 0.013127850090438997}}, "EndTime": 1613949848.066621, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066604}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013193773884270059, "sum": 0.013193773884270059, "min": 0.013193773884270059}}, "EndTime": 1613949848.066682, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066665}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013127679164685196, "sum": 0.013127679164685196, "min": 0.013127679164685196}}, "EndTime": 1613949848.066737, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066721}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013136238493512024, "sum": 0.013136238493512024, "min": 0.013136238493512024}}, "EndTime": 1613949848.066797, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.06678}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013258359701190162, "sum": 0.013258359701190162, "min": 0.013258359701190162}}, "EndTime": 1613949848.066868, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066848}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013136125135062328, "sum": 0.013136125135062328, "min": 0.013136125135062328}}, "EndTime": 1613949848.066932, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066913}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.013257740079757557, "sum": 0.013257740079757557, "min": 0.013257740079757557}}, "EndTime": 1613949848.066995, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949848.066977}
#
# [02/21/2021 23:24:08 INFO 140054048798528] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00479624264983
# [02/21/2021 23:24:08 INFO 140054048798528] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.004030335974
# [02/21/2021 23:24:08 INFO 140054048798528] Epoch 14: Loss improved. Updating best model
# [02/21/2021 23:24:08 INFO 140054048798528] Saving model for epoch: 14
# [02/21/2021 23:24:08 INFO 140054048798528] Saved checkpoint to "/tmp/tmpfggIo3/mx-mod-0000.params"
# [02/21/2021 23:24:08 INFO 140054048798528] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1613949848.074708, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613949841.151482}
#
# [02/21/2021 23:24:08 INFO 140054048798528] #throughput_metric: host=algo-1, train throughput=28795.8443374 records/second
# [02/21/2021 23:24:08 WARNING 140054048798528] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/21/2021 23:24:08 WARNING 140054048798528] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-02-21 23:24:08.082] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-02-21 23:24:08.747] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 662, "num_examples": 200, "num_bytes": 33493152}
# [2021-02-21 23:24:09.531] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 700, "num_examples": 200, "num_bytes": 33493152}
# [02/21/2021 23:24:09 INFO 140054048798528] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/21/2021 23:24:09 INFO 140054048798528] #train_score (algo-1) : ('binary_classification_accuracy', 0.9879416544611865)
# [02/21/2021 23:24:09 INFO 140054048798528] #train_score (algo-1) : ('binary_f_1.000', 0.21180327868852458)
# [02/21/2021 23:24:09 INFO 140054048798528] #train_score (algo-1) : ('precision', 0.11994058670627553)
# [02/21/2021 23:24:09 INFO 140054048798528] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/21/2021 23:24:09 INFO 140054048798528] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/21/2021 23:24:09 INFO 140054048798528] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00396091186531
# [02/21/2021 23:24:09 INFO 140054048798528] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.987941654461
# [02/21/2021 23:24:09 INFO 140054048798528] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.211803278689
# [02/21/2021 23:24:09 INFO 140054048798528] #quality_metric: host=algo-1, train precision <score>=0.119940586706
# [02/21/2021 23:24:09 INFO 140054048798528] #quality_metric: host=algo-1, train recall <score>=0.904761904762
# [02/21/2021 23:24:09 INFO 140054048798528] #quality_metric: host=algo-1, train roc_auc_score <score>=0.979089470538
# [02/21/2021 23:24:09 INFO 140054048798528] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [02/21/2021 23:24:09 INFO 140054048798528] Saved checkpoint to "/tmp/tmpWzczM9/mx-mod-0000.params"
# [02/21/2021 23:24:09 INFO 140054048798528] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 100299.85904693604, "sum": 100299.85904693604, "min": 100299.85904693604}, "finalize.time": {"count": 1, "max": 1516.3180828094482, "sum": 1516.3180828094482, "min": 1516.3180828094482}, "initialize.time": {"count": 1, "max": 216.4149284362793, "sum": 216.4149284362793, "min": 216.4149284362793}, "check_early_stopping.time": {"count": 15, "max": 1.0828971862792969, "sum": 14.315366744995117, "min": 0.820159912109375}, "setuptime": {"count": 1, "max": 26.772022247314453, "sum": 26.772022247314453, "min": 26.772022247314453}, "update.time": {"count": 15, "max": 7003.353834152222, "sum": 98194.92816925049, "min": 5886.770963668823}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1613949849.598236, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613949749.598468}
#
#
# 2021-02-21 23:24:29 Uploading - Uploading generated training model
# 2021-02-21 23:24:29 Completed - Training job completed
# ProfilerReport-1613949510: NoIssuesFound
# Training seconds: 179
# Billable seconds: 179
# CPU times: user 920 ms, sys: 32.2 ms, total: 952 ms
# Wall time: 6min 14s

# %% [markdown]
# ### Implantando e avaliando o estimador ajustado
#
# Nós criamos a hipótese que um modelo ajustado, otimizado para um recall alto, teria poucos falsos negativos (transações fraudulentas incorretamente rotuladas como válidas). Será que nosso modelo comprovará essa hipótese?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------------!CPU times: user 322 ms, sys: 29.5 ms, total: 352 ms
# Wall time: 9min 32s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.astype('float32').values, 
                   test_labels.values.reshape(-1,), 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84317  991
# 1                    20  115
#
# Recall:     0.852
# Precision:  0.104
# Accuracy:   0.988

# %% [markdown]
# ### Deletando o endpoint
#
# Como boa prática, todas as vezes que terminarmos de usar e avaliar um modelo, nós devemos deletar o endpoint. Assim, evitamos cobranças desnecessárias na AWS. Confia em mim, isso é importante.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-02-21-23-24-44-463

# %% [markdown]
# ---
# ## 2ª Melhoria: Lidando com o Desbalanceamento de Classes
#
# Nós já temos um modelo que está ajustado para obter um recall alto, que visa reduzir o número de falsos negativos. Anteriormente, nós falamos sobre como classes desbalanceadas podem gerar um viés no nosso modelo para prever todas as transações como válidas, resultando em uma grande quantidade de falsos negativos (transação fraudulenta, prevista como válida) e verdadeiros negativos (transação válida, prevista como válida). Tal fato levanta a hipótese que podemos melhorar o desempenho do nosso modelo se levarmos em consideração o desbalanceamento.
#
# Para levar em consideração o desbalanceamento de classes durante o treinamento do classificador binário, LinerLearner oferece o hiperparâmetro, `positive_example_weight_mult`, que funciona como um peso  atribuído para registros fraudulentos (1, fraudulento) usado durante o treinamento do classificador. O peso de registros negativos (0, válido) é fixo em 1.
#
# Além disso, para ajustar um modelo para um recall alto, você pode adicionar um parâmetro que ajuda a lidar com o desbalanceamento de classes. Atravpes da [documentação de hiperparâmetros](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) sobre `positive_example_weight_mult`, vemos em tradução livre:
#
# > "Se você quer que o algoritmo escolha um peso de tal forma que erros na classificação de exemplos negativa vs. positiva tenham o mesmo impacto no loss do treinamento, espeficifique `balanced`."

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9, # 90% recall
                              positive_example_weight_mult='balanced')
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Treinando o estimador balanceado
#
# Agora, vamos treinar o novo estimador balanceado no conjunto de treinamento formatado.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-21 23:37:45 Starting - Starting the training job...
# 2021-02-21 23:38:08 Starting - Launching requested ML instancesProfilerReport-1613950664: InProgress
# ......
# 2021-02-21 23:39:09 Starting - Preparing the instances for training.........
# 2021-02-21 23:40:45 Downloading - Downloading input data
# 2021-02-21 23:40:45 Training - Downloading the training image...
# 2021-02-21 23:41:10 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/21/2021 23:41:10 INFO 140307782559552] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/21/2021 23:41:10 INFO 140307782559552] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [02/21/2021 23:41:10 INFO 140307782559552] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [02/21/2021 23:41:10 WARNING 140307782559552] Loggers have already been setup.
# Process 1 is a worker.
# [02/21/2021 23:41:10 INFO 140307782559552] Using default worker.
# [02/21/2021 23:41:10 INFO 140307782559552] Checkpoint loading and saving are disabled.
# [2021-02-21 23:41:10.484] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 29, "num_examples": 1, "num_bytes": 168000}
# [02/21/2021 23:41:10 INFO 140307782559552] Create Store: local
# [2021-02-21 23:41:10.579] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 93, "num_examples": 11, "num_bytes": 1848000}
# [02/21/2021 23:41:10 INFO 140307782559552] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f9b9c0bfe10>
# [02/21/2021 23:41:10 INFO 140307782559552] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/21/2021 23:41:10 INFO 140307782559552] nvidia-smi took: 0.0252039432526 secs to identify 0 gpus
# [02/21/2021 23:41:10 INFO 140307782559552] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1613950870.776576, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613950870.776545}
#
# [2021-02-21 23:41:17.789] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7013, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5791407177028943, "sum": 0.5791407177028943, "min": 0.5791407177028943}}, "EndTime": 1613950877.790052, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.789969}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4759549259971734, "sum": 0.4759549259971734, "min": 0.4759549259971734}}, "EndTime": 1613950877.790156, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790134}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4948354150206599, "sum": 0.4948354150206599, "min": 0.4948354150206599}}, "EndTime": 1613950877.790233, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790212}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5374999441789023, "sum": 0.5374999441789023, "min": 0.5374999441789023}}, "EndTime": 1613950877.790288, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.79027}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6132990110579447, "sum": 0.6132990110579447, "min": 0.6132990110579447}}, "EndTime": 1613950877.790354, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790337}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.650242357378629, "sum": 0.650242357378629, "min": 0.650242357378629}}, "EndTime": 1613950877.790424, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790406}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6198758794314897, "sum": 0.6198758794314897, "min": 0.6198758794314897}}, "EndTime": 1613950877.790476, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.79046}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.642763320194417, "sum": 0.642763320194417, "min": 0.642763320194417}}, "EndTime": 1613950877.790542, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790525}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4923872120919539, "sum": 0.4923872120919539, "min": 0.4923872120919539}}, "EndTime": 1613950877.790606, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790587}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5910773196579823, "sum": 0.5910773196579823, "min": 0.5910773196579823}}, "EndTime": 1613950877.790672, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790654}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5660034152850434, "sum": 0.5660034152850434, "min": 0.5660034152850434}}, "EndTime": 1613950877.790736, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790718}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.570866738247512, "sum": 0.570866738247512, "min": 0.570866738247512}}, "EndTime": 1613950877.790808, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.79079}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.603102036327573, "sum": 0.603102036327573, "min": 0.603102036327573}}, "EndTime": 1613950877.790868, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790851}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6313092581015736, "sum": 0.6313092581015736, "min": 0.6313092581015736}}, "EndTime": 1613950877.790929, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790912}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6069122777967597, "sum": 0.6069122777967597, "min": 0.6069122777967597}}, "EndTime": 1613950877.790989, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.790972}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6302709089116235, "sum": 0.6302709089116235, "min": 0.6302709089116235}}, "EndTime": 1613950877.79105, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791033}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6274360078591198, "sum": 0.6274360078591198, "min": 0.6274360078591198}}, "EndTime": 1613950877.791116, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791097}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.512769868476906, "sum": 0.512769868476906, "min": 0.512769868476906}}, "EndTime": 1613950877.791169, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791153}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5364223231790054, "sum": 0.5364223231790054, "min": 0.5364223231790054}}, "EndTime": 1613950877.791233, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791216}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5448161246141596, "sum": 0.5448161246141596, "min": 0.5448161246141596}}, "EndTime": 1613950877.791296, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791278}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.540332931163922, "sum": 0.540332931163922, "min": 0.540332931163922}}, "EndTime": 1613950877.791356, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791339}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.541313360655128, "sum": 0.541313360655128, "min": 0.541313360655128}}, "EndTime": 1613950877.791416, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791399}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.536809625117623, "sum": 0.536809625117623, "min": 0.536809625117623}}, "EndTime": 1613950877.791484, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791466}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5356268091920632, "sum": 0.5356268091920632, "min": 0.5356268091920632}}, "EndTime": 1613950877.791547, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.79153}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.081357410986819, "sum": 1.081357410986819, "min": 1.081357410986819}}, "EndTime": 1613950877.79161, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791593}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807654687315975, "sum": 1.0807654687315975, "min": 1.0807654687315975}}, "EndTime": 1613950877.791671, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791653}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.107846775994229, "sum": 1.107846775994229, "min": 1.107846775994229}}, "EndTime": 1613950877.791732, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791714}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0852037635688208, "sum": 1.0852037635688208, "min": 1.0852037635688208}}, "EndTime": 1613950877.791794, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791777}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2230319136423082, "sum": 1.2230319136423082, "min": 1.2230319136423082}}, "EndTime": 1613950877.791861, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791843}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.240264271721768, "sum": 1.240264271721768, "min": 1.240264271721768}}, "EndTime": 1613950877.791924, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791907}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2185808203615736, "sum": 1.2185808203615736, "min": 1.2185808203615736}}, "EndTime": 1613950877.791982, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.791965}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2268015014801792, "sum": 1.2268015014801792, "min": 1.2268015014801792}}, "EndTime": 1613950877.792044, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950877.792027}
#
# [02/21/2021 23:41:17 INFO 140307782559552] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.579140717703
# [02/21/2021 23:41:17 INFO 140307782559552] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.475954925997
# [02/21/2021 23:41:17 INFO 140307782559552] Epoch 0: Loss improved. Updating best model
# [02/21/2021 23:41:17 INFO 140307782559552] Saving model for epoch: 0
# [02/21/2021 23:41:17 INFO 140307782559552] Saved checkpoint to "/tmp/tmpgX0Nii/mx-mod-0000.params"
# [02/21/2021 23:41:17 INFO 140307782559552] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1613950877.807098, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613950870.776777}
#
# [02/21/2021 23:41:17 INFO 140307782559552] #throughput_metric: host=algo-1, train throughput=28357.3142339 records/second
# [2021-02-21 23:41:24.993] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7185, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3762333395109704, "sum": 0.3762333395109704, "min": 0.3762333395109704}}, "EndTime": 1613950884.993642, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.993544}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3452077499849712, "sum": 0.3452077499849712, "min": 0.3452077499849712}}, "EndTime": 1613950884.993742, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.993719}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3545212267391646, "sum": 0.3545212267391646, "min": 0.3545212267391646}}, "EndTime": 1613950884.993811, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.993791}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.358282039009746, "sum": 0.358282039009746, "min": 0.358282039009746}}, "EndTime": 1613950884.99388, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.99386}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.503855560801137, "sum": 0.503855560801137, "min": 0.503855560801137}}, "EndTime": 1613950884.993948, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.993928}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5762882809279553, "sum": 0.5762882809279553, "min": 0.5762882809279553}}, "EndTime": 1613950884.994014, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.993995}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5095617222809912, "sum": 0.5095617222809912, "min": 0.5095617222809912}}, "EndTime": 1613950884.994081, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994062}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5621733702846508, "sum": 0.5621733702846508, "min": 0.5621733702846508}}, "EndTime": 1613950884.994148, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994129}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.35608179332023887, "sum": 0.35608179332023887, "min": 0.35608179332023887}}, "EndTime": 1613950884.994213, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994194}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37639001955578677, "sum": 0.37639001955578677, "min": 0.37639001955578677}}, "EndTime": 1613950884.994286, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994269}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3734735677901225, "sum": 0.3734735677901225, "min": 0.3734735677901225}}, "EndTime": 1613950884.994349, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994332}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3714105723778806, "sum": 0.3714105723778806, "min": 0.3714105723778806}}, "EndTime": 1613950884.994409, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994392}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4968251642581806, "sum": 0.4968251642581806, "min": 0.4968251642581806}}, "EndTime": 1613950884.994471, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994453}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5793348179342759, "sum": 0.5793348179342759, "min": 0.5793348179342759}}, "EndTime": 1613950884.994533, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994515}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5010429530119777, "sum": 0.5010429530119777, "min": 0.5010429530119777}}, "EndTime": 1613950884.994595, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994577}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5806286224671944, "sum": 0.5806286224671944, "min": 0.5806286224671944}}, "EndTime": 1613950884.994658, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.99464}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45959482746986885, "sum": 0.45959482746986885, "min": 0.45959482746986885}}, "EndTime": 1613950884.994718, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.9947}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45221469054869073, "sum": 0.45221469054869073, "min": 0.45221469054869073}}, "EndTime": 1613950884.994789, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994771}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4510753076447913, "sum": 0.4510753076447913, "min": 0.4510753076447913}}, "EndTime": 1613950884.994855, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994838}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45293791068379, "sum": 0.45293791068379, "min": 0.45293791068379}}, "EndTime": 1613950884.994915, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994897}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.513988640119083, "sum": 0.513988640119083, "min": 0.513988640119083}}, "EndTime": 1613950884.994986, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.994966}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5301194904844965, "sum": 0.5301194904844965, "min": 0.5301194904844965}}, "EndTime": 1613950884.995047, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.99503}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5141575448309357, "sum": 0.5141575448309357, "min": 0.5141575448309357}}, "EndTime": 1613950884.99511, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995093}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5306000879949062, "sum": 0.5306000879949062, "min": 0.5306000879949062}}, "EndTime": 1613950884.995182, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995163}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0809531622651833, "sum": 1.0809531622651833, "min": 1.0809531622651833}}, "EndTime": 1613950884.995252, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995235}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806157694294225, "sum": 1.0806157694294225, "min": 1.0806157694294225}}, "EndTime": 1613950884.995323, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995305}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0811927944164181, "sum": 1.0811927944164181, "min": 1.0811927944164181}}, "EndTime": 1613950884.995393, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995375}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806420212942152, "sum": 1.0806420212942152, "min": 1.0806420212942152}}, "EndTime": 1613950884.995454, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995438}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1822309901558574, "sum": 1.1822309901558574, "min": 1.1822309901558574}}, "EndTime": 1613950884.995521, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995504}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2228483647485475, "sum": 1.2228483647485475, "min": 1.2228483647485475}}, "EndTime": 1613950884.995587, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995571}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1816888533549093, "sum": 1.1816888533549093, "min": 1.1816888533549093}}, "EndTime": 1613950884.995644, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.99563}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2195927194566583, "sum": 1.2195927194566583, "min": 1.2195927194566583}}, "EndTime": 1613950884.995701, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950884.995683}
#
# [02/21/2021 23:41:24 INFO 140307782559552] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.376233339511
# [02/21/2021 23:41:24 INFO 140307782559552] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.345207749985
# [02/21/2021 23:41:24 INFO 140307782559552] Epoch 1: Loss improved. Updating best model
# [02/21/2021 23:41:25 INFO 140307782559552] Saving model for epoch: 1
# [02/21/2021 23:41:25 INFO 140307782559552] Saved checkpoint to "/tmp/tmp3IeEmr/mx-mod-0000.params"
# [02/21/2021 23:41:25 INFO 140307782559552] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1613950885.003624, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613950877.808329}
#
# [02/21/2021 23:41:25 INFO 140307782559552] #throughput_metric: host=algo-1, train throughput=27707.1655133 records/second
# [2021-02-21 23:41:31.330] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6325, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3391149269755761, "sum": 0.3391149269755761, "min": 0.3391149269755761}}, "EndTime": 1613950891.330938, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.330853}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3195404147047493, "sum": 0.3195404147047493, "min": 0.3195404147047493}}, "EndTime": 1613950891.331019, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331005}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32698557615040535, "sum": 0.32698557615040535, "min": 0.32698557615040535}}, "EndTime": 1613950891.331067, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331055}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3274032881846979, "sum": 0.3274032881846979, "min": 0.3274032881846979}}, "EndTime": 1613950891.331119, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331107}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4777964639903313, "sum": 0.4777964639903313, "min": 0.4777964639903313}}, "EndTime": 1613950891.331167, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331156}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.590638911990065, "sum": 0.590638911990065, "min": 0.590638911990065}}, "EndTime": 1613950891.331208, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331198}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.48253254189802774, "sum": 0.48253254189802774, "min": 0.48253254189802774}}, "EndTime": 1613950891.331248, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331238}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6031271160259918, "sum": 0.6031271160259918, "min": 0.6031271160259918}}, "EndTime": 1613950891.331294, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331283}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3290663219432735, "sum": 0.3290663219432735, "min": 0.3290663219432735}}, "EndTime": 1613950891.331339, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331329}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33843334504707373, "sum": 0.33843334504707373, "min": 0.33843334504707373}}, "EndTime": 1613950891.33138, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331369}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33953402284401746, "sum": 0.33953402284401746, "min": 0.33953402284401746}}, "EndTime": 1613950891.331425, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331415}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3347382457100566, "sum": 0.3347382457100566, "min": 0.3347382457100566}}, "EndTime": 1613950891.331472, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331461}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43369665937567475, "sum": 0.43369665937567475, "min": 0.43369665937567475}}, "EndTime": 1613950891.331513, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331503}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5582932119513276, "sum": 0.5582932119513276, "min": 0.5582932119513276}}, "EndTime": 1613950891.331551, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331541}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.40992417111229057, "sum": 0.40992417111229057, "min": 0.40992417111229057}}, "EndTime": 1613950891.331591, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331581}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5464452117843245, "sum": 0.5464452117843245, "min": 0.5464452117843245}}, "EndTime": 1613950891.331636, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331625}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44801290402819766, "sum": 0.44801290402819766, "min": 0.44801290402819766}}, "EndTime": 1613950891.331676, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331666}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4507313074466571, "sum": 0.4507313074466571, "min": 0.4507313074466571}}, "EndTime": 1613950891.331717, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331707}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4471608550872036, "sum": 0.4471608550872036, "min": 0.4471608550872036}}, "EndTime": 1613950891.331757, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331747}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4506483911868915, "sum": 0.4506483911868915, "min": 0.4506483911868915}}, "EndTime": 1613950891.331811, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.3318}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5034817837087353, "sum": 0.5034817837087353, "min": 0.5034817837087353}}, "EndTime": 1613950891.331856, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331846}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5302559648638394, "sum": 0.5302559648638394, "min": 0.5302559648638394}}, "EndTime": 1613950891.331895, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331885}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5034230974091957, "sum": 0.5034230974091957, "min": 0.5034230974091957}}, "EndTime": 1613950891.331932, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331923}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.531876334511455, "sum": 0.531876334511455, "min": 0.531876334511455}}, "EndTime": 1613950891.33197, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.33196}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080485231179089, "sum": 1.080485231179089, "min": 1.080485231179089}}, "EndTime": 1613950891.332006, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.331997}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806065483668341, "sum": 1.0806065483668341, "min": 1.0806065483668341}}, "EndTime": 1613950891.332044, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332034}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080347275623724, "sum": 1.080347275623724, "min": 1.080347275623724}}, "EndTime": 1613950891.332081, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332071}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807068119528305, "sum": 1.0807068119528305, "min": 1.0807068119528305}}, "EndTime": 1613950891.332118, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332108}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1454150128388525, "sum": 1.1454150128388525, "min": 1.1454150128388525}}, "EndTime": 1613950891.332155, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332145}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2139291877171503, "sum": 1.2139291877171503, "min": 1.2139291877171503}}, "EndTime": 1613950891.332192, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332182}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1451639179632291, "sum": 1.1451639179632291, "min": 1.1451639179632291}}, "EndTime": 1613950891.332233, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332223}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2131926508764526, "sum": 1.2131926508764526, "min": 1.2131926508764526}}, "EndTime": 1613950891.332262, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950891.332255}
#
# [02/21/2021 23:41:31 INFO 140307782559552] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.339114926976
# [02/21/2021 23:41:31 INFO 140307782559552] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.319540414705
# [02/21/2021 23:41:31 INFO 140307782559552] Epoch 2: Loss improved. Updating best model
# [02/21/2021 23:41:31 INFO 140307782559552] Saving model for epoch: 2
# [02/21/2021 23:41:31 INFO 140307782559552] Saved checkpoint to "/tmp/tmpXIO2aD/mx-mod-0000.params"
# [02/21/2021 23:41:31 INFO 140307782559552] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1613950891.340487, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613950885.004911}
#
# [02/21/2021 23:41:31 INFO 140307782559552] #throughput_metric: host=algo-1, train throughput=31466.7876374 records/second
# [2021-02-21 23:41:37.903] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6561, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32226599174767884, "sum": 0.32226599174767884, "min": 0.32226599174767884}}, "EndTime": 1613950897.903751, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613950897.903671}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3074733453491824, "sum": 0.3074733453491824, "min": 0.3074733453491824}}, "EndTime": 1613950897.903856, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613950897.903833}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2863595398946024, "sum": 0.2863595398946024, "min": 0.2863595398946024}}, "EndTime": 1613950969.572025, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572017}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28373790798474796, "sum": 0.28373790798474796, "min": 0.28373790798474796}}, "EndTime": 1613950969.572056, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572048}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5330752930856829, "sum": 0.5330752930856829, "min": 0.5330752930856829}}, "EndTime": 1613950969.572095, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572081}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28378996158005604, "sum": 0.28378996158005604, "min": 0.28378996158005604}}, "EndTime": 1613950969.572144, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572134}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.47326236121019527, "sum": 0.47326236121019527, "min": 0.47326236121019527}}, "EndTime": 1613950969.572174, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572167}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29130650279749576, "sum": 0.29130650279749576, "min": 0.29130650279749576}}, "EndTime": 1613950969.572202, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572195}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29114658903955815, "sum": 0.29114658903955815, "min": 0.29114658903955815}}, "EndTime": 1613950969.572229, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572222}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29353761303005504, "sum": 0.29353761303005504, "min": 0.29353761303005504}}, "EndTime": 1613950969.572259, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572249}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2908794963204082, "sum": 0.2908794963204082, "min": 0.2908794963204082}}, "EndTime": 1613950969.572309, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572298}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2914942595515419, "sum": 0.2914942595515419, "min": 0.2914942595515419}}, "EndTime": 1613950969.572346, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572332}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4870187229367357, "sum": 0.4870187229367357, "min": 0.4870187229367357}}, "EndTime": 1613950969.572407, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.57239}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2914134636116986, "sum": 0.2914134636116986, "min": 0.2914134636116986}}, "EndTime": 1613950969.572471, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572454}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.49398941992754913, "sum": 0.49398941992754913, "min": 0.49398941992754913}}, "EndTime": 1613950969.572535, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572518}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4376009713177705, "sum": 0.4376009713177705, "min": 0.4376009713177705}}, "EndTime": 1613950969.572608, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572591}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4484181482516342, "sum": 0.4484181482516342, "min": 0.4484181482516342}}, "EndTime": 1613950969.57268, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572661}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43762711445410646, "sum": 0.43762711445410646, "min": 0.43762711445410646}}, "EndTime": 1613950969.572741, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572725}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44841468803367424, "sum": 0.44841468803367424, "min": 0.44841468803367424}}, "EndTime": 1613950969.572805, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572788}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45202172866897966, "sum": 0.45202172866897966, "min": 0.45202172866897966}}, "EndTime": 1613950969.572868, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.57285}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5203195825893077, "sum": 0.5203195825893077, "min": 0.5203195825893077}}, "EndTime": 1613950969.572932, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572915}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4520227471739803, "sum": 0.4520227471739803, "min": 0.4520227471739803}}, "EndTime": 1613950969.572994, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.572977}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5202868180394772, "sum": 0.5202868180394772, "min": 0.5202868180394772}}, "EndTime": 1613950969.573054, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573038}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0734474260339786, "sum": 1.0734474260339786, "min": 1.0734474260339786}}, "EndTime": 1613950969.573117, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573099}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0808105422743601, "sum": 1.0808105422743601, "min": 1.0808105422743601}}, "EndTime": 1613950969.57318, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573163}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.073446477075318, "sum": 1.073446477075318, "min": 1.073446477075318}}, "EndTime": 1613950969.573268, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573249}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0808158106204853, "sum": 1.0808158106204853, "min": 1.0808158106204853}}, "EndTime": 1613950969.573333, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573315}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.081110000226965, "sum": 1.081110000226965, "min": 1.081110000226965}}, "EndTime": 1613950969.5734, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573382}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.178819695554187, "sum": 1.178819695554187, "min": 1.178819695554187}}, "EndTime": 1613950969.573471, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573452}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0811094335814817, "sum": 1.0811094335814817, "min": 1.0811094335814817}}, "EndTime": 1613950969.573544, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573525}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1788132949905779, "sum": 1.1788132949905779, "min": 1.1788132949905779}}, "EndTime": 1613950969.573607, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950969.573589}
#
# [02/21/2021 23:42:49 INFO 140307782559552] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.290683084536
# [02/21/2021 23:42:49 INFO 140307782559552] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.283737907985
# [02/21/2021 23:42:49 INFO 140307782559552] Epoch 14: Loss improved. Updating best model
# [02/21/2021 23:42:49 INFO 140307782559552] Saving model for epoch: 14
# [02/21/2021 23:42:49 INFO 140307782559552] Saved checkpoint to "/tmp/tmp_UlrxG/mx-mod-0000.params"
# [02/21/2021 23:42:49 INFO 140307782559552] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1613950969.581169, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1613950962.905152}
#
# [02/21/2021 23:42:49 INFO 140307782559552] #throughput_metric: host=algo-1, train throughput=29862.1655494 records/second
# [02/21/2021 23:42:49 WARNING 140307782559552] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/21/2021 23:42:49 WARNING 140307782559552] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-02-21 23:42:49.588] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2021-02-21 23:42:50.249] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 657, "num_examples": 200, "num_bytes": 33493152}
# [2021-02-21 23:42:51.031] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 711, "num_examples": 200, "num_bytes": 33493152}
# [02/21/2021 23:42:51 INFO 140307782559552] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2687483957430368)
# [02/21/2021 23:42:51 INFO 140307782559552] #train_score (algo-1) : ('binary_classification_accuracy', 0.9913173892979675)
# [02/21/2021 23:42:51 INFO 140307782559552] #train_score (algo-1) : ('binary_f_1.000', 0.27177114009255365)
# [02/21/2021 23:42:51 INFO 140307782559552] #train_score (algo-1) : ('precision', 0.1599009900990099)
# [02/21/2021 23:42:51 INFO 140307782559552] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/21/2021 23:42:51 INFO 140307782559552] #train_score (algo-1) : ('roc_auc_score', 0.9883347149127631)
# [02/21/2021 23:42:51 INFO 140307782559552] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.268748395743
# [02/21/2021 23:42:51 INFO 140307782559552] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.991317389298
# [02/21/2021 23:42:51 INFO 140307782559552] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.271771140093
# [02/21/2021 23:42:51 INFO 140307782559552] #quality_metric: host=algo-1, train precision <score>=0.159900990099
# [02/21/2021 23:42:51 INFO 140307782559552] #quality_metric: host=algo-1, train recall <score>=0.904761904762
# [02/21/2021 23:42:51 INFO 140307782559552] #quality_metric: host=algo-1, train roc_auc_score <score>=0.988334714913
# [02/21/2021 23:42:51 INFO 140307782559552] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [02/21/2021 23:42:51 INFO 140307782559552] Saved checkpoint to "/tmp/tmpBbHjrx/mx-mod-0000.params"
# [02/21/2021 23:42:51 INFO 140307782559552] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 100905.91192245483, "sum": 100905.91192245483, "min": 100905.91192245483}, "finalize.time": {"count": 1, "max": 1504.3351650238037, "sum": 1504.3351650238037, "min": 1504.3351650238037}, "initialize.time": {"count": 1, "max": 317.2750473022461, "sum": 317.2750473022461, "min": 317.2750473022461}, "check_early_stopping.time": {"count": 15, "max": 1.0840892791748047, "sum": 12.94398307800293, "min": 0.7660388946533203}, "setuptime": {"count": 1, "max": 26.797056198120117, "sum": 26.797056198120117, "min": 26.797056198120117}, "update.time": {"count": 15, "max": 7192.974805831909, "sum": 98742.8388595581, "min": 6061.025142669678}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1613950971.095604, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613950870.453954}
#
#
# 2021-02-21 23:43:12 Uploading - Uploading generated training model
# 2021-02-21 23:43:12 Completed - Training job completed
# ProfilerReport-1613950664: NoIssuesFound
# Training seconds: 142
# Billable seconds: 142
# CPU times: user 844 ms, sys: 54.6 ms, total: 899 ms
# Wall time: 5min 43s

# %% [markdown]
# ### Implantando e avaliando o estimador balanceado
#
# Após o treinamento, vamos agora implantar o modelo treinado e avaliar sua performance.

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ---------------------!CPU times: user 367 ms, sys: 17.5 ms, total: 384 ms
# Wall time: 10min 33s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32').values, 
                   test_labels.values.reshape(-1,), 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84629  679
# 1                    18  117
#
# Recall:     0.867
# Precision:  0.147
# Accuracy:   0.992

# %% [markdown]
# ### Deletando o endpoint
#
# Como boa prática, inclusive para o nosso bolso, vamos deletar o endpoint após seu uso.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-02-22-00-14-21-124

# %% [markdown]
# Uma observação sobre variabilidade de métricas:
#
# O modelo acima está ajustado para a melhor precisão possível com o recall fixo em aproximadamente 90%. O recall foi fixado, porém pode variar quando nós usamos nosso modelo treinado em um conjunto de dados de teste.

# %% [markdown]
# ---
# ## Arquitetura do Modelo
#
# Agora que nós vimos como ajustar e balancear um LinearLearner, no próximo exercício vamos ganhar mais prática com projetar um modelo com uma arquitetura que o otimiza para um cenário específico e implantá-lo usando o SageMaker.
#
# **Cenário:**
#
# * Um banco solicita a você para construir um modelo que otimiza os resultados para uma melhor experiência do usuário, isto é, o modelo **não** deve detectar uma transação válida de um usuário como fraudulenta mais do que 15% das vezes.
#
# Tal requisito requer que nós tomemos uma desisão de arquitetura: dado o cenário acima, qual métrica (e valor) nós devemos configurar para o modelo atingir durante o treinamento?
#
# Podemos assumir que no conjunto de treinamento obteremos aproximadamente de 5 a 10% de performance a mais do que no conjunto de teste.
#
# Logo, o modelo abaixo deve levar em consideração o desbalanceamento de classes e os ajustes necessários para solucionar os requisitos nesse cenário.

# %%
# %%time
# instantiate and train a LinearLearner

# include params for tuning for higher precision
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='recall_at_target_precision', # target precision
                              target_precision =0.90, # 15% precision
                              positive_example_weight_mult='balanced')

linear_balanced.fit(formatted_train_data)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-02-22 00:52:06 Starting - Starting the training job...
# 2021-02-22 00:52:29 Starting - Launching requested ML instancesProfilerReport-1613955126: InProgress
# .........
# 2021-02-22 00:53:50 Starting - Preparing the instances for training.........
# 2021-02-22 00:55:34 Downloading - Downloading input data
# 2021-02-22 00:55:34 Training - Downloading the training image...
# 2021-02-22 00:55:54 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/22/2021 00:55:59 INFO 139990947239744] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [02/22/2021 00:55:59 INFO 139990947239744] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'target_precision': u'0.9', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'epochs': u'15', u'positive_example_weight_mult': u'balanced', u'mini_batch_size': u'1000'}
# [02/22/2021 00:55:59 INFO 139990947239744] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'use_lr_scheduler': u'true', u'target_precision': u'0.9', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [02/22/2021 00:55:59 WARNING 139990947239744] Loggers have already been setup.
# Process 1 is a worker.
# [02/22/2021 00:55:59 INFO 139990947239744] Using default worker.
# [02/22/2021 00:55:59 INFO 139990947239744] Checkpoint loading and saving are disabled.
# [2021-02-22 00:55:59.836] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 21, "num_examples": 1, "num_bytes": 168000}
# [02/22/2021 00:55:59 INFO 139990947239744] Create Store: local
# [2021-02-22 00:55:59.931] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 93, "num_examples": 11, "num_bytes": 1848000}
# [02/22/2021 00:55:59 INFO 139990947239744] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f51cf30fdd0>
# [02/22/2021 00:55:59 INFO 139990947239744] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/22/2021 00:55:59 INFO 139990947239744] nvidia-smi took: 0.0252571105957 secs to identify 0 gpus
# [02/22/2021 00:55:59 INFO 139990947239744] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1613955360.125068, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1613955360.125023}
#
# [2021-02-22 00:56:07.506] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7380, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5791407177028943, "sum": 0.5791407177028943, "min": 0.5791407177028943}}, "EndTime": 1613955367.506492, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.506382}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4759549259971734, "sum": 0.4759549259971734, "min": 0.4759549259971734}}, "EndTime": 1613955367.506599, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.506576}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4948354150206599, "sum": 0.4948354150206599, "min": 0.4948354150206599}}, "EndTime": 1613955367.506672, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50665}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5374999441789023, "sum": 0.5374999441789023, "min": 0.5374999441789023}}, "EndTime": 1613955367.506754, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.506734}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6132990110579447, "sum": 0.6132990110579447, "min": 0.6132990110579447}}, "EndTime": 1613955367.506878, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.506811}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.650242357378629, "sum": 0.650242357378629, "min": 0.650242357378629}}, "EndTime": 1613955367.506962, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.506942}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6198758794314897, "sum": 0.6198758794314897, "min": 0.6198758794314897}}, "EndTime": 1613955367.507036, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507019}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.642763320194417, "sum": 0.642763320194417, "min": 0.642763320194417}}, "EndTime": 1613955367.507098, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50708}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4923872120919539, "sum": 0.4923872120919539, "min": 0.4923872120919539}}, "EndTime": 1613955367.50716, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507142}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5910773196579823, "sum": 0.5910773196579823, "min": 0.5910773196579823}}, "EndTime": 1613955367.507228, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50721}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5660034152850434, "sum": 0.5660034152850434, "min": 0.5660034152850434}}, "EndTime": 1613955367.507303, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507283}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.570866738247512, "sum": 0.570866738247512, "min": 0.570866738247512}}, "EndTime": 1613955367.50738, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50736}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.603102036327573, "sum": 0.603102036327573, "min": 0.603102036327573}}, "EndTime": 1613955367.507454, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507434}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6313092581015736, "sum": 0.6313092581015736, "min": 0.6313092581015736}}, "EndTime": 1613955367.507515, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507498}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6069122777967597, "sum": 0.6069122777967597, "min": 0.6069122777967597}}, "EndTime": 1613955367.50758, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507562}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6302709089116235, "sum": 0.6302709089116235, "min": 0.6302709089116235}}, "EndTime": 1613955367.507649, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507631}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6274360078591198, "sum": 0.6274360078591198, "min": 0.6274360078591198}}, "EndTime": 1613955367.507713, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507696}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.512769868476906, "sum": 0.512769868476906, "min": 0.512769868476906}}, "EndTime": 1613955367.507756, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507741}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5364223231790054, "sum": 0.5364223231790054, "min": 0.5364223231790054}}, "EndTime": 1613955367.507814, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507797}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5448161246141596, "sum": 0.5448161246141596, "min": 0.5448161246141596}}, "EndTime": 1613955367.507874, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507857}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.540332931163922, "sum": 0.540332931163922, "min": 0.540332931163922}}, "EndTime": 1613955367.507937, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507919}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.541313360655128, "sum": 0.541313360655128, "min": 0.541313360655128}}, "EndTime": 1613955367.508001, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.507979}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.536809625117623, "sum": 0.536809625117623, "min": 0.536809625117623}}, "EndTime": 1613955367.508065, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508047}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5356268091920632, "sum": 0.5356268091920632, "min": 0.5356268091920632}}, "EndTime": 1613955367.508135, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508117}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.081357410986819, "sum": 1.081357410986819, "min": 1.081357410986819}}, "EndTime": 1613955367.508205, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508187}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807654687315975, "sum": 1.0807654687315975, "min": 1.0807654687315975}}, "EndTime": 1613955367.508267, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50825}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.107846775994229, "sum": 1.107846775994229, "min": 1.107846775994229}}, "EndTime": 1613955367.508329, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508312}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0852037635688208, "sum": 1.0852037635688208, "min": 1.0852037635688208}}, "EndTime": 1613955367.508398, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508382}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2230319136423082, "sum": 1.2230319136423082, "min": 1.2230319136423082}}, "EndTime": 1613955367.508458, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508441}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.240264271721768, "sum": 1.240264271721768, "min": 1.240264271721768}}, "EndTime": 1613955367.508518, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.508501}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2185808203615736, "sum": 1.2185808203615736, "min": 1.2185808203615736}}, "EndTime": 1613955367.508576, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50856}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2268015014801792, "sum": 1.2268015014801792, "min": 1.2268015014801792}}, "EndTime": 1613955367.508634, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955367.50862}
#
# [02/22/2021 00:56:07 INFO 139990947239744] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.579140717703
# [02/22/2021 00:56:07 INFO 139990947239744] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.475954925997
# [02/22/2021 00:56:07 INFO 139990947239744] Epoch 0: Loss improved. Updating best model
# [02/22/2021 00:56:07 INFO 139990947239744] Saving model for epoch: 0
# [02/22/2021 00:56:07 INFO 139990947239744] Saved checkpoint to "/tmp/tmpFyPozw/mx-mod-0000.params"
# [02/22/2021 00:56:07 INFO 139990947239744] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1613955367.52099, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1613955360.125282}
#
# [02/22/2021 00:56:07 INFO 139990947239744] #throughput_metric: host=algo-1, train throughput=26956.2603136 records/second
# [2021-02-22 00:56:14.505] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6983, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3762333395109704, "sum": 0.3762333395109704, "min": 0.3762333395109704}}, "EndTime": 1613955374.506104, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506015}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3452077499849712, "sum": 0.3452077499849712, "min": 0.3452077499849712}}, "EndTime": 1613955374.506223, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506204}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3545212267391646, "sum": 0.3545212267391646, "min": 0.3545212267391646}}, "EndTime": 1613955374.5063, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506284}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.358282039009746, "sum": 0.358282039009746, "min": 0.358282039009746}}, "EndTime": 1613955374.506348, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506336}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.503855560801137, "sum": 0.503855560801137, "min": 0.503855560801137}}, "EndTime": 1613955374.50639, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506379}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5762882809279553, "sum": 0.5762882809279553, "min": 0.5762882809279553}}, "EndTime": 1613955374.506479, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506464}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5095617222809912, "sum": 0.5095617222809912, "min": 0.5095617222809912}}, "EndTime": 1613955374.506522, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506511}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5621733702846508, "sum": 0.5621733702846508, "min": 0.5621733702846508}}, "EndTime": 1613955374.506564, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506554}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.35608179332023887, "sum": 0.35608179332023887, "min": 0.35608179332023887}}, "EndTime": 1613955374.506636, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506622}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.37639001955578677, "sum": 0.37639001955578677, "min": 0.37639001955578677}}, "EndTime": 1613955374.506692, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506681}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3734735677901225, "sum": 0.3734735677901225, "min": 0.3734735677901225}}, "EndTime": 1613955374.506739, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506728}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3714105723778806, "sum": 0.3714105723778806, "min": 0.3714105723778806}}, "EndTime": 1613955374.506785, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506774}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4968251642581806, "sum": 0.4968251642581806, "min": 0.4968251642581806}}, "EndTime": 1613955374.506825, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506815}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5793348179342759, "sum": 0.5793348179342759, "min": 0.5793348179342759}}, "EndTime": 1613955374.506892, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506879}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5010429530119777, "sum": 0.5010429530119777, "min": 0.5010429530119777}}, "EndTime": 1613955374.50694, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506928}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5806286224671944, "sum": 0.5806286224671944, "min": 0.5806286224671944}}, "EndTime": 1613955374.506982, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.506971}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45959482746986885, "sum": 0.45959482746986885, "min": 0.45959482746986885}}, "EndTime": 1613955374.507026, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507015}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45221469054869073, "sum": 0.45221469054869073, "min": 0.45221469054869073}}, "EndTime": 1613955374.507072, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507061}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4510753076447913, "sum": 0.4510753076447913, "min": 0.4510753076447913}}, "EndTime": 1613955374.507118, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507107}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45293791068379, "sum": 0.45293791068379, "min": 0.45293791068379}}, "EndTime": 1613955374.507164, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507153}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.513988640119083, "sum": 0.513988640119083, "min": 0.513988640119083}}, "EndTime": 1613955374.507214, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.5072}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5301194904844965, "sum": 0.5301194904844965, "min": 0.5301194904844965}}, "EndTime": 1613955374.507261, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507252}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5141575448309357, "sum": 0.5141575448309357, "min": 0.5141575448309357}}, "EndTime": 1613955374.507322, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507306}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5306000879949062, "sum": 0.5306000879949062, "min": 0.5306000879949062}}, "EndTime": 1613955374.507386, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.50737}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0809531622651833, "sum": 1.0809531622651833, "min": 1.0809531622651833}}, "EndTime": 1613955374.507451, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507435}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806157694294225, "sum": 1.0806157694294225, "min": 1.0806157694294225}}, "EndTime": 1613955374.507513, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507496}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0811927944164181, "sum": 1.0811927944164181, "min": 1.0811927944164181}}, "EndTime": 1613955374.507569, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507553}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806420212942152, "sum": 1.0806420212942152, "min": 1.0806420212942152}}, "EndTime": 1613955374.507612, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507598}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1822309901558574, "sum": 1.1822309901558574, "min": 1.1822309901558574}}, "EndTime": 1613955374.507669, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507652}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2228483647485475, "sum": 1.2228483647485475, "min": 1.2228483647485475}}, "EndTime": 1613955374.50773, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507713}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1816888533549093, "sum": 1.1816888533549093, "min": 1.1816888533549093}}, "EndTime": 1613955374.507781, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507765}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2195927194566583, "sum": 1.2195927194566583, "min": 1.2195927194566583}}, "EndTime": 1613955374.507844, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955374.507828}
#
# [02/22/2021 00:56:14 INFO 139990947239744] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.376233339511
# [02/22/2021 00:56:14 INFO 139990947239744] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.345207749985
# [02/22/2021 00:56:14 INFO 139990947239744] Epoch 1: Loss improved. Updating best model
# [02/22/2021 00:56:14 INFO 139990947239744] Saving model for epoch: 1
# [02/22/2021 00:56:14 INFO 139990947239744] Saved checkpoint to "/tmp/tmpSLZ7Ge/mx-mod-0000.params"
# [02/22/2021 00:56:14 INFO 139990947239744] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1613955374.516076, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1613955367.522308}
#
# [02/22/2021 00:56:14 INFO 139990947239744] #throughput_metric: host=algo-1, train throughput=28505.4806051 records/second
# [2021-02-22 00:56:21.479] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6962, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3391149269755761, "sum": 0.3391149269755761, "min": 0.3391149269755761}}, "EndTime": 1613955381.479781, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.479697}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3195404147047493, "sum": 0.3195404147047493, "min": 0.3195404147047493}}, "EndTime": 1613955381.479862, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.479847}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32698557615040535, "sum": 0.32698557615040535, "min": 0.32698557615040535}}, "EndTime": 1613955381.479918, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.479905}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3274032881846979, "sum": 0.3274032881846979, "min": 0.3274032881846979}}, "EndTime": 1613955381.479971, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.479959}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4777964639903313, "sum": 0.4777964639903313, "min": 0.4777964639903313}}, "EndTime": 1613955381.480021, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480009}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.590638911990065, "sum": 0.590638911990065, "min": 0.590638911990065}}, "EndTime": 1613955381.480069, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480057}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.48253254189802774, "sum": 0.48253254189802774, "min": 0.48253254189802774}}, "EndTime": 1613955381.480114, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480103}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6031271160259918, "sum": 0.6031271160259918, "min": 0.6031271160259918}}, "EndTime": 1613955381.480154, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480144}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3290663219432735, "sum": 0.3290663219432735, "min": 0.3290663219432735}}, "EndTime": 1613955381.4802, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480189}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33843334504707373, "sum": 0.33843334504707373, "min": 0.33843334504707373}}, "EndTime": 1613955381.480248, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480236}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.33953402284401746, "sum": 0.33953402284401746, "min": 0.33953402284401746}}, "EndTime": 1613955381.480295, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480284}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3347382457100566, "sum": 0.3347382457100566, "min": 0.3347382457100566}}, "EndTime": 1613955381.480338, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480328}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.43369665937567475, "sum": 0.43369665937567475, "min": 0.43369665937567475}}, "EndTime": 1613955381.480386, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480374}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5582932119513276, "sum": 0.5582932119513276, "min": 0.5582932119513276}}, "EndTime": 1613955381.480438, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480428}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.40992417111229057, "sum": 0.40992417111229057, "min": 0.40992417111229057}}, "EndTime": 1613955381.480483, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480472}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5464452117843245, "sum": 0.5464452117843245, "min": 0.5464452117843245}}, "EndTime": 1613955381.480523, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480513}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44801290402819766, "sum": 0.44801290402819766, "min": 0.44801290402819766}}, "EndTime": 1613955381.480568, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480557}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4507313074466571, "sum": 0.4507313074466571, "min": 0.4507313074466571}}, "EndTime": 1613955381.480614, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480602}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4471608550872036, "sum": 0.4471608550872036, "min": 0.4471608550872036}}, "EndTime": 1613955381.480659, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480648}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4506483911868915, "sum": 0.4506483911868915, "min": 0.4506483911868915}}, "EndTime": 1613955381.480705, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480694}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5034817837087353, "sum": 0.5034817837087353, "min": 0.5034817837087353}}, "EndTime": 1613955381.480752, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480741}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5302559648638394, "sum": 0.5302559648638394, "min": 0.5302559648638394}}, "EndTime": 1613955381.480797, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480786}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5034230974091957, "sum": 0.5034230974091957, "min": 0.5034230974091957}}, "EndTime": 1613955381.480842, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.48083}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.531876334511455, "sum": 0.531876334511455, "min": 0.531876334511455}}, "EndTime": 1613955381.480886, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480875}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080485231179089, "sum": 1.080485231179089, "min": 1.080485231179089}}, "EndTime": 1613955381.480924, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480914}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0806065483668341, "sum": 1.0806065483668341, "min": 1.0806065483668341}}, "EndTime": 1613955381.480969, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.480958}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080347275623724, "sum": 1.080347275623724, "min": 1.080347275623724}}, "EndTime": 1613955381.481014, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.481004}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807068119528305, "sum": 1.0807068119528305, "min": 1.0807068119528305}}, "EndTime": 1613955381.481065, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.48105}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1454150128388525, "sum": 1.1454150128388525, "min": 1.1454150128388525}}, "EndTime": 1613955381.481122, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.481106}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2139291877171503, "sum": 1.2139291877171503, "min": 1.2139291877171503}}, "EndTime": 1613955381.481156, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.481148}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1451639179632291, "sum": 1.1451639179632291, "min": 1.1451639179632291}}, "EndTime": 1613955381.481184, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.481176}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2131926508764526, "sum": 1.2131926508764526, "min": 1.2131926508764526}}, "EndTime": 1613955381.48121, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955381.481203}
#
# [02/22/2021 00:56:21 INFO 139990947239744] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.339114926976
# [02/22/2021 00:56:21 INFO 139990947239744] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.319540414705
# [02/22/2021 00:56:21 INFO 139990947239744] Epoch 2: Loss improved. Updating best model
# [02/22/2021 00:56:21 INFO 139990947239744] Saving model for epoch: 2
# [02/22/2021 00:56:21 INFO 139990947239744] Saved checkpoint to "/tmp/tmpXSlOMM/mx-mod-0000.params"
# [02/22/2021 00:56:21 INFO 139990947239744] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1613955381.489292, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1613955374.517373}
#
# [02/22/2021 00:56:21 INFO 139990947239744] #throughput_metric: host=algo-1, train throughput=28594.8324135 records/second
# [2021-02-22 00:56:28.160] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6669, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32226599174767884, "sum": 0.32226599174767884, "min": 0.32226599174767884}}, "EndTime": 1613955388.160453, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613955388.16036}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3074733453491824, "sum": 0.3074733453491824, "min": 0.3074733453491824}}, "EndTime": 1613955388.160545, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1613955388.160525}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0874263988092316, "sum": 1.0874263988092316, "min": 1.0874263988092316}}, "EndTime": 1613955420.256788, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1613955420.256775}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.193349668723255, "sum": 1.193349668723255, "min": 1.193349668723255}}, "EndTime": 1613955420.256867, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1613955420.256849}
#
# [02/22/2021 00:57:00 INFO 139990947239744] #quality_metric: host=algo-1, epoch=8, train binary_classification_weighted_cross_entropy_objective <loss>=0.29712837641
# [02/22/2021 00:57:00 INFO 139990947239744] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=binary_classification_weighted_cross_entropy_objective, value=0.290708784401
# [02/22/2021 00:57:00 INFO 139990947239744] Epoch 8: Loss improved. Updating best model
# [02/22/2021 00:57:00 INFO 139990947239744] Saving model for epoch: 8
# [02/22/2021 00:57:00 INFO 139990947239744] Saved checkpoint to "/tmp/tmpkrb6px/mx-mod-0000.params"
# [02/22/2021 00:57:00 INFO 139990947239744] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 1812, "sum": 1812.0, "min": 1812}, "Total Records Seen": {"count": 1, "max": 1806276, "sum": 1806276.0, "min": 1806276}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1613955420.265286, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 8}, "StartTime": 1613955413.940411}
#
# [02/22/2021 00:57:00 INFO 139990947239744] #throughput_metric: host=algo-1, train throughput=31520.0698625 records/second
# [2021-02-22 00:57:07.544] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 7277, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2953641708987442, "sum": 0.2953641708987442, "min": 0.2953641708987442}}, "EndTime": 1613955427.544789, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.544543}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.28941299503652296, "sum": 0.28941299503652296, "min": 0.28941299503652296}}, "EndTime": 1613955427.544986, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.544954}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2918349039279037, "sum": 0.2918349039279037, "min": 0.2918349039279037}}, "EndTime": 1613955427.545142, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.5451}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29118323267644375, "sum": 0.29118323267644375, "min": 0.29118323267644375}}, "EndTime": 1613955427.545271, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.54525}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31175755904307917, "sum": 0.31175755904307917, "min": 0.31175755904307917}}, "EndTime": 1613955427.545416, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.54538}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5355660047483205, "sum": 0.5355660047483205, "min": 0.5355660047483205}}, "EndTime": 1613955427.545532, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.545511}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.31327311836894434, "sum": 0.31327311836894434, "min": 0.31327311836894434}}, "EndTime": 1613955427.545659, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.545638}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4868964618031104, "sum": 0.4868964618031104, "min": 0.4868964618031104}}, "EndTime": 1613955427.545789, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.545766}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29526167914615803, "sum": 0.29526167914615803, "min": 0.29526167914615803}}, "EndTime": 1613955427.545857, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.545839}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2955229419344035, "sum": 0.2955229419344035, "min": 0.2955229419344035}}, "EndTime": 1613955427.54593, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.545912}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.2981015085191583, "sum": 0.2981015085191583, "min": 0.2981015085191583}}, "EndTime": 1613955427.545995, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.545978}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.29484313539284557, "sum": 0.29484313539284557, "min": 0.29484313539284557}}, "EndTime": 1613955427.546059, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546042}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.316016094226933, "sum": 0.316016094226933, "min": 0.316016094226933}}, "EndTime": 1613955427.546124, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546107}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5078505934422939, "sum": 0.5078505934422939, "min": 0.5078505934422939}}, "EndTime": 1613955427.546187, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546169}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3147183538082257, "sum": 0.3147183538082257, "min": 0.3147183538082257}}, "EndTime": 1613955427.546247, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.54623}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.461936165344775, "sum": 0.461936165344775, "min": 0.461936165344775}}, "EndTime": 1613955427.546305, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546289}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4393228930756075, "sum": 0.4393228930756075, "min": 0.4393228930756075}}, "EndTime": 1613955427.546363, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546347}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4492769595198895, "sum": 0.4492769595198895, "min": 0.4492769595198895}}, "EndTime": 1613955427.546425, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546407}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4394711234701339, "sum": 0.4394711234701339, "min": 0.4394711234701339}}, "EndTime": 1613955427.546486, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546469}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44926908621476525, "sum": 0.44926908621476525, "min": 0.44926908621476525}}, "EndTime": 1613955427.546543, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546527}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4627772839800197, "sum": 0.4627772839800197, "min": 0.4627772839800197}}, "EndTime": 1613955427.546603, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546586}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5242887667171919, "sum": 0.5242887667171919, "min": 0.5242887667171919}}, "EndTime": 1613955427.546664, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546647}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4627765382929663, "sum": 0.4627765382929663, "min": 0.4627765382929663}}, "EndTime": 1613955427.546725, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546708}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5242206533997502, "sum": 0.5242206533997502, "min": 0.5242206533997502}}, "EndTime": 1613955427.546782, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546766}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0753970536275126, "sum": 1.0753970536275126, "min": 1.0753970536275126}}, "EndTime": 1613955427.546866, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546825}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.080709679838401, "sum": 1.080709679838401, "min": 1.080709679838401}}, "EndTime": 1613955427.546933, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546915}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.075383125956933, "sum": 1.075383125956933, "min": 1.075383125956933}}, "EndTime": 1613955427.546992, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.546976}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0807346745016586, "sum": 1.0807346745016586, "min": 1.0807346745016586}}, "EndTime": 1613955427.547053, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.547036}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0864507947758815, "sum": 1.0864507947758815, "min": 1.0864507947758815}}, "EndTime": 1613955427.547112, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.547095}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1904928500688257, "sum": 1.1904928500688257, "min": 1.1904928500688257}}, "EndTime": 1613955427.547174, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.547157}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.0864383847030563, "sum": 1.0864383847030563, "min": 1.0864383847030563}}, "EndTime": 1613955427.547236, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.547219}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.1904888488922887, "sum": 1.1904888488922887, "min": 1.1904888488922887}}, "EndTime": 1613955427.547295, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955427.547279}
#
# [02/22/2021 00:57:07 INFO 139990947239744] #quality_metric: host=algo-1, epoch=9, train binary_classification_weighted_cross_entropy_objective <loss>=0.295364170899
# [02/22/2021 00:57:07 INFO 139990947239744] #early_stopping_criteria_metric: host=algo-1, epoch=9, criteria=binary_classification_weighted_cross_entropy_objective, value=0.289412995037
# [02/22/2021 00:57:07 INFO 139990947239744] Epoch 9: Loss improved. Updating best model
# [02/22/2021 00:57:07 INFO 139990947239744] Saving model for epoch: 9
# [02/22/2021 00:57:07 INFO 139990947239744] Saved checkpoint to "/tmp/tmp0NNk_o/mx-mod-0000.params"
# [02/22/2021 00:57:07 INFO 139990947239744] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 2012, "sum": 2012.0, "min": 2012}, "Total Records Seen": {"count": 1, "max": 2005640, "sum": 2005640.0, "min": 2005640}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1613955427.559706, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 9}, "StartTime": 1613955420.266679}
#
# [02/22/2021 00:57:07 INFO 139990947239744] #throughput_metric: host=algo-1, train throughput=27335.8665251 records/second
#
# 2021-02-22 00:57:53 Uploading - Uploading generated training model
# 2021-02-22 00:57:53 Completed - Training job completed
# Training seconds: 150
# Billable seconds: 150
# CPU times: user 878 ms, sys: 33.1 ms, total: 911 ms
# Wall time: 6min 14s

# %%
# %%time 
# deploy and evaluate a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor,
                   test_features.astype('float32').values,
                   test_labels.values.reshape(-1,),
                   verbose=True)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------------!prediction (col)    0.0    1.0
# actual (row)
# 0                 59727  25581
# 1                     3    132
#
# Recall:     0.978
# Precision:  0.005
# Accuracy:   0.701
#
# CPU times: user 6.21 s, sys: 65.5 ms, total: 6.27 s
# Wall time: 9min 46s

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
delete_endpoint(balanced_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2021-02-22-01-41-00-979

# %% [markdown]
# ## Limpeza Final
#
# Trantando-se de AWS ou qualquer outro serviço em nuvem, é sempre uma boa prática conferir quais recursos foram criados e precisam ser deletados ou desligados, evitando cobranças adicionais desnecessárias.
#
# * Confira novamente se você deletou todos os seus endpoints;
# * Também é sugerido que você manualmente delete os buckets S3 criados e as configurações de endpoint diretamente do seu AWS Console.

# %% [markdown]
# ## Conclusão
#
# Neste notebook, nós pudemos entender mais sobre como treinar e implantar um classificador (LinearLearner) no SageMaker para detectar transações fraudulentas de cartão de crédito. Esse modelo foi ajustado e projetado para melhor atender a cenários específicos e melhorar a performance ao gerenciar o desbalanceamento de classes no conjunto de treinamento.
#
# Seguindo os passos de um fluxo de trabalho (workflow) de Machine Learning, foi possível carregar um conjunto de dados com transações de cartão de crédito, explorar e preparar os dados para inserí-los no modelo para o treinamento. Após treinamos, implantamos e avaliamos vários modelos de acordo com cenários específicos.

# %% [markdown]
# Este notebook foi traduzido e comentado a partir do notebook de exercício de ['Fraud_Detection_Exercise.ipynb'](https://github.com/udacity/ML_SageMaker_Studies/blob/master/Payment_Fraud_Detection/Fraud_Detection_Exercise.ipynb) durante o programa de nanodegree de Engenharia de Machine Learning da Udacity. Meu especial agradecimento à Udacity e aos materiais de alta qualidade disponibilizados.
